# %%
from wordcounter.wordcounter import WordCounter 
import re
import nltk
nltk.download('wordnet')
nltk.download('stopwords')

from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import textcleaner as tc

# files are in ./bag-of-words.txt
words = {}
bag_of_words_file = 'bag-of-words.txt'

print('hello')
# Out:
# hello
# [nltk_data] Downloading package wordnet to /Users/merrin/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/merrin/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
with open(bag_of_words_file) as f:
    contents = f.read()
    contents = contents.replace('\n', ' ')
    contents = re.sub('[^0-9a-zA-Zā]+', ' ', contents)
    contents = contents.lower()
    data = tc.document(contents)
    contents = data.remove_stpwrds()
    
print("hello again")
# Out:
# hello again
# let shining beacon best practice forward thinking nz people known creative practical problem solving skills let use skills best ability environment precious gift must preserve new zealand citizen extremely concerned new zealand lack action side stepping climate change date thankful finally see climate change addressed holistic way commend involved making happen climate change needs taken seriously changes need make drastic important government gives clear leadership changes easy needs clear path zero crucial organisations held accountable exposure people given information require make informed decisions interaction companies could impact global environment proud kiwi zero carbon bill act guiding future happen good see government willing something let hard conversations move brighter cleaner smarter future ps consider top policy housing wealth taxation way free people finances homes stop people scared climate change destroying equity mean money invest new tech thank initiative know another country showing leadership preparation temptation say oh nz small make difference leadership like ring around world think fantastic well researched document makes important first step congratulations order maximum benefit need ensure high proportion nz people engage requires lot targeted marketing needs strong stakeholder communications management strategy great job well done would welcome discussions subject want give feedback legislative changes support climate change relating electric vehicles might aware issues around electric car batteries present bought nissan leaf aware batteries presently imported country current laws classify dangerous substance however allowed imported inside car lack replacement batteries putting lot people buying leafs used japanese imports particularly older ones less reliable batteries need replacement need change legislation soon possible support safe import refurbished batteries japan electric cars also need incentivise car manufacturers produce batteries nz support nz companies trying replicate batteries produce home hope also support mining substances used car batteries currently available mined nz environmentally friendly way sell substances use develop ev battery industry nz big demand around world bill important future hope make work data sharing consent happy submission put website please remove name email online privacy bit concern days thank time essence targets need bolder guts collaboration among different agencies essential buckle issue vitally important also huge opportunity current system fine need changed paramount importance soils role recognised issue order encourage farming practice increase soils organic matter great deal carbon stored soil stored atmosphere 30 co2 countered humus building based upon top 15cm graeme saite humus saves world ted talk moreover estimated 1 increase us crop lands alone would take take 4 5 billion tonnes co2 atmosphere return soil recognition principle applied nz huge benefit proposed carbon budgets althought bill lot promise believe imperative put safeguards place stop change government progress reverse power also ets broken keep important stay focused goal zero carbon new zealand changes today effect future children environment document lacks specific ideas exactly reduce emissions target setting ok need discuss exactly meet targets survival species appropriate species world government needs work humans serve commission must independent lack conflicts interest business interests authority set new rules targets enforce inaction behalf govt must transparent possible work behalf people profit spine stand powerful business interests vested interests conflict health environment also needs lot focus agriculture impact environment single largest contributor greenhouse gasses done immense damage environment need held responsible must adapt changes must made save environment end day think essential take responsibility nation emissions reaching target net zero emissions 20 ...

# %%
wnl = WordNetLemmatizer()

tokens = word_tokenize(" ".join(contents))

lemmatized_words = [wnl.lemmatize(token) for token in tokens]

word_counter = WordCounter(" ".join(lemmatized_words))
freq = word_counter.get_word_frequencies()

s = sorted(frequencies.items(), key=lambda kv: kv[1])

print(s)

# %%
word_counter = WordCounter(contents)

frequencies = word_counter.get_word_frequencies()

s = sorted(frequencies.items(), key=lambda kv: kv[1])

print(s)

# %%
from nltk.corpus import stopwords

stopwords.words('english')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
