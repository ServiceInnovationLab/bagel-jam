# %%
import json
from glob import glob

# %%
def sort_by_line_number(elem):
    return elem['line_number']

def sort_by_weight(elem):
    return elem['weight']

# %%
key_phrases_file = 'zero-carbon-bill/key-phrases/key-phrases.json'
with open(key_phrases_file) as f:
    contents = f.read()

key_phrases = json.loads(contents)

# %%
sentiment_analysis_file = 'zero-carbon-bill/sentiment-analysis/output.json'
with open(sentiment_analysis_file) as f:
    contents = f.read()

raw_sentiment_analysis = json.loads(contents)
sentiment_analysis = {}

for item in raw_sentiment_analysis:
    filename = item['File']
    if sentiment_analysis.get(filename, None) is None:
        sentiment_analysis[filename] = []
    sentiment_analysis[filename].append(item)

sentiment_analysis
# Out:
# {'00004_Anonymous.json': [{'File': '00004_Anonymous.json',
#    'Line': 2,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00004_Anonymous.json',
#    'Line': 3,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00004_Anonymous.json',
#    'Line': 4,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00004_Anonymous.json',
#    'Line': 5,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00004_Anonymous.json',
#    'Line': 6,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00004_Anonymous.json',
#    'Line': 0,
#    'Sentiment': 'NEGATIVE',
#    'SentimentScore': {'Mixed': 9.223462257068604e-05,
#     'Negative': 0.6324755549430847,
#     'Neutral': 0.3533305525779724,
#     'Positive': 0.014101650565862656}},
#   {'File': '00004_Anonymous.json',
#    'Line': 1,
#    'Sentiment': 'NEGATIVE',
#    'SentimentScore': {'Mixed': 0.00019403127953410149,
#     'Negative': 0.397066205739975,
#     'Neutral': 0.38760659098625183,
#     'Positive': 0.2151332050561905}}],
#  '00009_Anonymous.json': [{'File': '00009_Anonymous.json',
#    'Line': 2,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00009_Anonymous.json',
#    'Line': 3,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00009_Anonymous.json',
#    'Line': 4,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00009_Anonymous.json',
#    'Line': 5,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00009_Anonymous.json',
#    'Line': 6,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00009_Anonymous.json',
#    'Line': 0,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 6.681379545625532e-06,
#     'Negative': 0.009062699973583221,
#     'Neutral': 0.716634213924408,
#     'Positive': 0.2742964029312134}},
#   {'File': '00009_Anonymous.json',
#    'Line': 1,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 6.047413990017958e-06,
#     'Negative': 0.019138121977448463,
#     'Neutral': 0.9752217531204224,
#     'Positive': 0.0056341043673455715}}],
#  '00014_Mike_Gwyther_Redacted.json': [{'File': '00014_Mike_Gwyther_Redacted.json',
#    'Line': 2,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00014_Mike_Gwyther_Redacted.json',
#    'Line': 4,
#    'Sentiment': 'NEGATIVE',
#    'SentimentScore': {'Mixed': 7.248082692967728e-05,
#     'Negative': 0.577781617641449,
#     'Neutral': 0.2536259591579437,
#     'Positive': 0.16851995885372162}},
#   {'File': '00014_Mike_Gwyther_Redacted.json',
#    'Line': 0,
#    'Sentiment': 'POSITIVE',
#    'SentimentScore': {'Mixed': 0.07330172508955002,
#     'Negative': 0.07968558371067047,
#     'Neutral': 0.3418622612953186,
#     'Positive': 0.5051504969596863}},
#   {'File': '00014_Mike_Gwyther_Redacted.json',
#    'Line': 1,
#    'Sentiment': 'MIXED',
#    'SentimentScore': {'Mixed': 0.8418945074081421,
#     'Negative': 0.003029078943654895,
#     'Neutral': 0.043712716549634933,
#     'Positive': 0.11136369407176971}},
#   {'File': '00014_Mike_Gwyther_Redacted.json',
#    'Line': 3,
#    'Sentiment': 'MIXED',
#    'SentimentScore': {'Mixed': 0.7426666021347046,
#     'Negative': 0.11674073338508606,
#     'Neutral': 0.12277799099683762,
#     'Positive': 0.017814604565501213}}],
#  '00017_Simon_Jackson_Redacted.json': [{'File': '00017_Simon_Jackson_Redacted.json',
#    'Line': 1,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00017_Simon_Jackson_Redacted.json',
#    'Line': 0,
#    'Sentiment': 'POSITIVE',
#    'SentimentScore': {'Mixed': 1.1556237950571813e-05,
#     'Negative': 0.0028689659666270018,
#     'Neutral': 0.0480431504547596,
#     'Positive': 0.9490762948989868}},
#   {'File': '00017_Simon_Jackson_Redacted.json',
#    'Line': 2,
#    'Sentiment': 'POSITIVE',
#    'SentimentScore': {'Mixed': 0.008839519694447517,
#     'Negative': 0.03863660991191864,
#     'Neutral': 0.329031765460968,
#     'Positive': 0.6234920620918274}}],
#  '00018_Leigh_Nicholson_Redacted.json': [{'File': '00018_Leigh_Nicholson_Redacted.json',
#    'Line': 1,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00018_Leigh_Nicholson_Redacted.json',
#    'Line': 4,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 1.5788742757649743e-06,
#     'Negative': 0.0007019431213848293,
#     'Neutral': 0.991081714630127,
#     'Positive': 0.008214765228331089}},
#   {'File': '00018_Leigh_Nicholson_Redacted.json',
#    'Line': 0,
#    'Sentiment': 'POSITIVE',
#    'SentimentScore': {'Mixed': 8.502266268806125e-07,
#     'Negative': 2.525704439904075e-05,
#     'Neutral': 0.0002052847557934001,
#     'Positive': 0.9997685551643372}},
#   {'File': '00018_Leigh_Nicholson_Redacted.json',
#    'Line': 2,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.0001730922667775303,
#     'Negative': 0.356216698884964,
#     'Neutral': 0.43769529461860657,
#     'Positive': 0.2059149444103241}},
#   {'File': '00018_Leigh_Nicholson_Redacted.json',
#    'Line': 3,
#    'Sentiment': 'POSITIVE',
#    'SentimentScore': {'Mixed': 2.777309055090882e-05,
#     'Negative': 0.003264286322519183,
#     'Neutral': 0.036262258887290955,
#     'Positive': 0.9604456424713135}}],
#  '00019_Linda_Bond_Redacted.json': [{'File': '00019_Linda_Bond_Redacted.json',
#    'Line': 2,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00019_Linda_Bond_Redacted.json',
#    'Line': 5,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00019_Linda_Bond_Redacted.json',
#    'Line': 8,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00019_Linda_Bond_Redacted.json',
#    'Line': 11,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00019_Linda_Bond_Redacted.json',
#    'Line': 1,
#    'Sentiment': 'NEGATIVE',
#    'SentimentScore': {'Mixed': 0.000210620419238694,
#     'Negative': 0.5743558406829834,
#     'Neutral': 0.36481523513793945,
#     'Positive': 0.0606183186173439}},
#   {'File': '00019_Linda_Bond_Redacted.json',
#    'Line': 4,
#    'Sentiment': 'NEGATIVE',
#    'SentimentScore': {'Mixed': 0.0044937096536159515,
#     'Negative': 0.9268785715103149,
#     'Neutral': 0.038510944694280624,
#     'Positive': 0.0301167331635952}},
#   {'File': '00019_Linda_Bond_Redacted.json',
#    'Line': 7,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 5.910019899602048e-05,
#     'Negative': 0.22688068449497223,
#     'Neutral': 0.7614221572875977,
#     'Positive': 0.011638080701231956}},
#   {'File': '00019_Linda_Bond_Redacted.json',
#    'Line': 9,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.0022159044165164232,
#     'Negative': 0.3665107488632202,
#     'Neutral': 0.6066514253616333,
#     'Positive': 0.024621902033686638}},
#   {'File': '00019_Linda_Bond_Redacted.json',
#    'Line': 10,
#    'Sentiment': 'POSITIVE',
#    'SentimentScore': {'Mixed': 3.1060739274835214e-05,
#     'Negative': 0.02107062377035618,
#     'Neutral': 0.351126104593277,
#     'Positive': 0.6277722716331482}},
#   {'File': '00019_Linda_Bond_Redacted.json',
#    'Line': 12,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 2.3776428861310706e-05,
#     'Negative': 0.13855983316898346,
#     'Neutral': 0.7592735886573792,
#     'Positive': 0.10214278846979141}},
#   {'File': '00019_Linda_Bond_Redacted.json',
#    'Line': 0,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 2.7569226404011715e-06,
#     'Negative': 0.002306899521499872,
#     'Neutral': 0.8857455253601074,
#     'Positive': 0.11194486171007156}},
#   {'File': '00019_Linda_Bond_Redacted.json',
#    'Line': 3,
#    'Sentiment': 'NEGATIVE',
#    'SentimentScore': {'Mixed': 1.4552264246958657e-06,
#     'Negative': 0.9440008997917175,
#     'Neutral': 0.054483622312545776,
#     'Positive': 0.0015139892930164933}},
#   {'File': '00019_Linda_Bond_Redacted.json',
#    'Line': 6,
#    'Sentiment': 'NEGATIVE',
#    'SentimentScore': {'Mixed': 3.921033567166887e-05,
#     'Negative': 0.6499761939048767,
#     'Neutral': 0.3441573977470398,
#     'Positive': 0.005827215500175953}},
#   {'File': '00019_Linda_Bond_Redacted.json',
#    'Line': 13,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 1.4624512004957069e-05,
#     'Negative': 0.022992990911006927,
#     'Neutral': 0.9083533883094788,
#     'Positive': 0.06863905489444733}}],
#  '00023_Anonymous.json': [{'File': '00023_Anonymous.json',
#    'Line': 1,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00023_Anonymous.json',
#    'Line': 3,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00023_Anonymous.json',
#    'Line': 4,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00023_Anonymous.json',
#    'Line': 5,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00023_Anonymous.json',
#    'Line': 6,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00023_Anonymous.json',
#    'Line': 7,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00023_Anonymous.json',
#    'Line': 2,
#    'Sentiment': 'NEGATIVE',
#    'SentimentScore': {'Mixed': 8.589263597968966e-05,
#     'Negative': 0.9368301630020142,
#     'Neutral': 0.0542423240840435,
#     'Positive': 0.0088416188955307}},
#   {'File': '00023_Anonymous.json',
#    'Line': 0,
#    'Sentiment': 'POSITIVE',
#    'SentimentScore': {'Mixed': 1.915747816383373e-06,
#     'Negative': 0.0025058500468730927,
#     'Neutral': 0.24876618385314941,
#     'Positive': 0.7487260699272156}}],
#  '00028_Daniel_Oades_Redacted.json': [{'File': '00028_Daniel_Oades_Redacted.json',
#    'Line': 0,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 8.766161045059562e-06,
#     'Negative': 0.001329177524894476,
#     'Neutral': 0.8105012774467468,
#     'Positive': 0.1881607174873352}}],
#  '00030_Anonymous.json': [{'File': '00030_Anonymous.json',
#    'Line': 1,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00030_Anonymous.json',
#    'Line': 2,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00030_Anonymous.json',
#    'Line': 3,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00030_Anonymous.json',
#    'Line': 4,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00030_Anonymous.json',
#    'Line': 5,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00030_Anonymous.json',
#    'Line': 0,
#    'Sentiment': 'POSITIVE',
#    'SentimentScore': {'Mixed': 2.3933669581310824e-05,
#     'Negative': 0.03002927452325821,
#     'Neutral': 0.1414193958044052,
#     'Positive': 0.8285273909568787}}],
#  '00032_Richard_Blair_Laurenson_Redacted.json': [{'File': '00032_Richard_Blair_Laurenson_Redacted.json',
#    'Line': 2,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00032_Richard_Blair_Laurenson_Redacted.json',
#    'Line': 0,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 6.050625870557269e-06,
#     'Negative': 0.0015794195933267474,
#     'Neutral': 0.9388054609298706,
#     'Positive': 0.0596090629696846}},
#   {'File': '00032_Richard_Blair_Laurenson_Redacted.json',
#    'Line': 1,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 4.2520317947492003e-05,
#     'Negative': 0.02769356034696102,
#     'Neutral': 0.9286477565765381,
#     'Positive': 0.0436161570250988}},
#   {'File': '00032_Richard_Blair_Laurenson_Redacted.json',
#    'Line': 3,
#    'Sentiment': 'POSITIVE',
#    'SentimentScore': {'Mixed': 1.9854694983223453e-05,
#     'Negative': 0.0650114044547081,
#     'Neutral': 0.4654666483402252,
#     'Positive': 0.46950215101242065}},
#   {'File': '00032_Richard_Blair_Laurenson_Redacted.json',
#    'Line': 4,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 6.97199793648906e-05,
#     'Negative': 0.13311150670051575,
#     'Neutral': 0.8623970150947571,
#     'Positive': 0.004421813879162073}},
#   {'File': '00032_Richard_Blair_Laurenson_Redacted.json',
#    'Line': 6,
#    'Sentiment': 'POSITIVE',
#    'SentimentScore': {'Mixed': 3.4037159366562264e-06,
#     'Negative': 0.005090449471026659,
#     'Neutral': 0.21290947496891022,
#     'Positive': 0.7819966673851013}},
#   {'File': '00032_Richard_Blair_Laurenson_Redacted.json',
#    'Line': 5,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}}],
#  '00001_Deborah_Hide-Bayne_Redacted.json': [{'File': '00001_Deborah_Hide-Bayne_Redacted.json',
#    'Line': 0,
#    'Sentiment': 'POSITIVE',
#    'SentimentScore': {'Mixed': 2.0483355456235586e-06,
#     'Negative': 0.0006407052860595286,
#     'Neutral': 0.09965444356203079,
#     'Positive': 0.8997027277946472}},
#   {'File': '00001_Deborah_Hide-Bayne_Redacted.json',
#    'Line': 1,
#    'Sentiment': 'POSITIVE',
#    'SentimentScore': {'Mixed': 8.354824785783421e-06,
#     'Negative': 0.0014961023116484284,
#     'Neutral': 0.47125938534736633,
#     'Positive': 0.5272361040115356}}],
#  '00003_Siobhan_Lynch_Redacted.json': [{'File': '00003_Siobhan_Lynch_Redacted.json',
#    'Line': 0,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 4.0344486478716135e-05,
#     'Negative': 0.30640390515327454,
#     'Neutral': 0.672034740447998,
#     'Positive': 0.021520918235182762}},
#   {'File': '00003_Siobhan_Lynch_Redacted.json',
#    'Line': 1,
#    'Sentiment': 'POSITIVE',
#    'SentimentScore': {'Mixed': 2.8465907234931365e-05,
#     'Negative': 0.0017131413333117962,
#     'Neutral': 0.16217626631259918,
#     'Positive': 0.8360821604728699}}],
#  '00033_Ben_Mansfield_Redacted.json': [{'File': '00033_Ben_Mansfield_Redacted.json',
#    'Line': 0,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.13674652576446533,
#     'Negative': 0.02023702673614025,
#     'Neutral': 0.7630103230476379,
#     'Positive': 0.08000612258911133}},
#   {'File': '00033_Ben_Mansfield_Redacted.json',
#    'Line': 1,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00033_Ben_Mansfield_Redacted.json',
#    'Line': 2,
#    'Sentiment': 'NEGATIVE',
#    'SentimentScore': {'Mixed': 0.00034491100814193487,
#     'Negative': 0.6504178047180176,
#     'Neutral': 0.3465021550655365,
#     'Positive': 0.0027351677417755127}}],
#  '00034_Anonymous.json': [{'File': '00034_Anonymous.json',
#    'Line': 0,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 2.2658089164906414e-06,
#     'Negative': 0.0011025461135432124,
#     'Neutral': 0.6559454202651978,
#     'Positive': 0.342949777841568}},
#   {'File': '00034_Anonymous.json',
#    'Line': 1,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 3.0166987926349975e-05,
#     'Negative': 0.026432139798998833,
#     'Neutral': 0.9018645286560059,
#     'Positive': 0.07167311012744904}},
#   {'File': '00034_Anonymous.json',
#    'Line': 2,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00034_Anonymous.json',
#    'Line': 3,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00034_Anonymous.json',
#    'Line': 4,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00034_Anonymous.json',
#    'Line': 5,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00034_Anonymous.json',
#    'Line': 6,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}}],
#  '00037_Ronald_Richard_Apperley_Miller_Redacted.json': [{'File': '00037_Ronald_Richard_Apperley_Miller_Redacted.json',
#    'Line': 0,
#    'Sentiment': 'MIXED',
#    'SentimentScore': {'Mixed': 0.9300429821014404,
#     'Negative': 0.044991686940193176,
#     'Neutral': 0.022152433171868324,
#     'Positive': 0.002812897088006139}},
#   {'File': '00037_Ronald_Richard_Apperley_Miller_Redacted.json',
#    'Line': 1,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 5.367368066799827e-05,
#     'Negative': 0.022967208176851273,
#     'Neutral': 0.5460290908813477,
#     'Positive': 0.4309500455856323}}],
#  '00041_Anonymous.json': [{'File': '00041_Anonymous.json',
#    'Line': 0,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 7.849878784327302e-06,
#     'Negative': 0.024277176707983017,
#     'Neutral': 0.9690483808517456,
#     'Positive': 0.006666646804660559}},
#   {'File': '00041_Anonymous.json',
#    'Line': 1,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.0008825458935461938,
#     'Negative': 0.11697832494974136,
#     'Neutral': 0.6511480808258057,
#     'Positive': 0.2309909611940384}},
#   {'File': '00041_Anonymous.json',
#    'Line': 3,
#    'Sentiment': 'NEGATIVE',
#    'SentimentScore': {'Mixed': 0.00015459979476872832,
#     'Negative': 0.699245810508728,
#     'Neutral': 0.2628357708454132,
#     'Positive': 0.03776382654905319}},
#   {'File': '00041_Anonymous.json',
#    'Line': 4,
#    'Sentiment': 'NEGATIVE',
#    'SentimentScore': {'Mixed': 0.00013219345419202,
#     'Negative': 0.8182662725448608,
#     'Neutral': 0.16357110440731049,
#     'Positive': 0.018030386418104172}},
#   {'File': '00041_Anonymous.json',
#    'Line': 2,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00041_Anonymous.json',
#    'Line': 5,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00041_Anonymous.json',
#    'Line': 8,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00041_Anonymous.json',
#    'Line': 9,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00041_Anonymous.json',
#    'Line': 10,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00041_Anonymous.json',
#    'Line': 11,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00041_Anonymous.json',
#    'Line': 12,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00041_Anonymous.json',
#    'Line': 6,
#    'Sentiment': 'NEGATIVE',
#    'SentimentScore': {'Mixed': 0.0004720374126918614,
#     'Negative': 0.8249930739402771,
#     'Neutral': 0.1485152244567871,
#     'Positive': 0.026019662618637085}},
#   {'File': '00041_Anonymous.json',
#    'Line': 7,
#    'Sentiment': 'POSITIVE',
#    'SentimentScore': {'Mixed': 4.287921456125332e-06,
#     'Negative': 0.0041803657077252865,
#     'Neutral': 0.28476881980895996,
#     'Positive': 0.711046576499939}}],
#  '00044_Benjamin_Thomas_Hay-Smith_Redacted.json': [{'File': '00044_Benjamin_Thomas_Hay-Smith_Redacted.json',
#    'Line': 0,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 5.996778418193571e-05,
#     'Negative': 0.07077619433403015,
#     'Neutral': 0.8213691115379333,
#     'Positive': 0.10779475420713425}},
#   {'File': '00044_Benjamin_Thomas_Hay-Smith_Redacted.json',
#    'Line': 2,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00044_Benjamin_Thomas_Hay-Smith_Redacted.json',
#    'Line': 6,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00044_Benjamin_Thomas_Hay-Smith_Redacted.json',
#    'Line': 8,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 1.4182061931933276e-05,
#     'Negative': 0.002249708166345954,
#     'Neutral': 0.7604114413261414,
#     'Positive': 0.23732469975948334}},
#   {'File': '00044_Benjamin_Thomas_Hay-Smith_Redacted.json',
#    'Line': 1,
#    'Sentiment': 'NEGATIVE',
#    'SentimentScore': {'Mixed': 2.638129808474332e-05,
#     'Negative': 0.6295737624168396,
#     'Neutral': 0.3649201989173889,
#     'Positive': 0.005479657556861639}},
#   {'File': '00044_Benjamin_Thomas_Hay-Smith_Redacted.json',
#    'Line': 4,
#    'Sentiment': 'NEGATIVE',
#    'SentimentScore': {'Mixed': 0.0023957379162311554,
#     'Negative': 0.7384669780731201,
#     'Neutral': 0.1964678019285202,
#     'Positive': 0.0626695454120636}},
#   {'File': '00044_Benjamin_Thomas_Hay-Smith_Redacted.json',
#    'Line': 5,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.06327757239341736,
#     'Negative': 0.10457615554332733,
#     'Neutral': 0.7254335284233093,
#     'Positive': 0.10671277344226837}},
#   {'File': '00044_Benjamin_Thomas_Hay-Smith_Redacted.json',
#    'Line': 7,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 5.70774363950477e-06,
#     'Negative': 0.0018432046053931117,
#     'Neutral': 0.6496179103851318,
#     'Positive': 0.34853318333625793}},
#   {'File': '00044_Benjamin_Thomas_Hay-Smith_Redacted.json',
#    'Line': 3,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.0007184899877756834,
#     'Negative': 0.03296501934528351,
#     'Neutral': 0.9045839905738831,
#     'Positive': 0.061732519418001175}}],
#  '00050_Paul_Judge_Redacted.json': [{'File': '00050_Paul_Judge_Redacted.json',
#    'Line': 1,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00050_Paul_Judge_Redacted.json',
#    'Line': 0,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 6.901535925862845e-06,
#     'Negative': 0.0004318135906942189,
#     'Neutral': 0.6102367043495178,
#     'Positive': 0.3893245458602905}},
#   {'File': '00050_Paul_Judge_Redacted.json',
#    'Line': 2,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.00033293524757027626,
#     'Negative': 0.10981260240077972,
#     'Neutral': 0.8785468935966492,
#     'Positive': 0.011307649314403534}}],
#  '00051_Peter_Martin_Wallis_Redacted.json': [{'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 2,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 5,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 9,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 12,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 15,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 18,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 22,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 25,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 28,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 32,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 35,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 0,
#    'Sentiment': 'POSITIVE',
#    'SentimentScore': {'Mixed': 4.370339865999995e-06,
#     'Negative': 0.011354116722941399,
#     'Neutral': 0.33815622329711914,
#     'Positive': 0.6504852175712585}},
#   {'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 1,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 7.451098554156488e-06,
#     'Negative': 0.0022089926060289145,
#     'Neutral': 0.9798831343650818,
#     'Positive': 0.017900409176945686}},
#   {'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 3,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 4.531387276074383e-06,
#     'Negative': 0.006117419805377722,
#     'Neutral': 0.8729186654090881,
#     'Positive': 0.1209593117237091}},
#   {'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 4,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.0028895956929773092,
#     'Negative': 0.02068888209760189,
#     'Neutral': 0.7592204213142395,
#     'Positive': 0.2172010838985443}},
#   {'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 6,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.00022073106083553284,
#     'Negative': 0.012677405029535294,
#     'Neutral': 0.6335989236831665,
#     'Positive': 0.3535029888153076}},
#   {'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 8,
#    'Sentiment': 'NEGATIVE',
#    'SentimentScore': {'Mixed': 0.0010852123377844691,
#     'Negative': 0.5841357707977295,
#     'Neutral': 0.3994305431842804,
#     'Positive': 0.015348472632467747}},
#   {'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 10,
#    'Sentiment': 'NEGATIVE',
#    'SentimentScore': {'Mixed': 0.0006901394226588309,
#     'Negative': 0.8052247762680054,
#     'Neutral': 0.18956302106380463,
#     'Positive': 0.004522123374044895}},
#   {'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 11,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 1.1107988029834814e-05,
#     'Negative': 0.06531400978565216,
#     'Neutral': 0.6845995783805847,
#     'Positive': 0.2500753700733185}},
#   {'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 13,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 1.0270476195728406e-05,
#     'Negative': 0.03959960862994194,
#     'Neutral': 0.7336728572845459,
#     'Positive': 0.2267172932624817}},
#   {'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 14,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 1.3898026736569591e-05,
#     'Negative': 0.04848750680685043,
#     'Neutral': 0.8969952464103699,
#     'Positive': 0.05450337380170822}},
#   {'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 16,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.0010743204038590193,
#     'Negative': 0.32136085629463196,
#     'Neutral': 0.5447951555252075,
#     'Positive': 0.13276968896389008}},
#   {'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 17,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 6.031699740560725e-06,
#     'Negative': 0.00770484609529376,
#     'Neutral': 0.7031072974205017,
#     'Positive': 0.28918179869651794}},
#   {'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 19,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.0002817039785441011,
#     'Negative': 0.25482749938964844,
#     'Neutral': 0.6927691102027893,
#     'Positive': 0.05212172865867615}},
#   {'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 20,
#    'Sentiment': 'POSITIVE',
#    'SentimentScore': {'Mixed': 1.3608236258733086e-05,
#     'Negative': 0.005260020028799772,
#     'Neutral': 0.3807940185070038,
#     'Positive': 0.6139323115348816}},
#   {'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 21,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 6.708231467200676e-06,
#     'Negative': 0.028388790786266327,
#     'Neutral': 0.9702995419502258,
#     'Positive': 0.0013050413690507412}},
#   {'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 23,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 6.162629233585903e-06,
#     'Negative': 0.19843646883964539,
#     'Neutral': 0.42081335186958313,
#     'Positive': 0.38074392080307007}},
#   {'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 24,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 4.2872808990068734e-05,
#     'Negative': 0.15468162298202515,
#     'Neutral': 0.8341277837753296,
#     'Positive': 0.011147772893309593}},
#   {'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 26,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 8.038634859985905e-07,
#     'Negative': 0.0009159382316283882,
#     'Neutral': 0.9972248077392578,
#     'Positive': 0.0018584339413791895}},
#   {'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 27,
#    'Sentiment': 'NEGATIVE',
#    'SentimentScore': {'Mixed': 3.744334389921278e-05,
#     'Negative': 0.7845727801322937,
#     'Neutral': 0.21487778425216675,
#     'Positive': 0.0005120254354551435}},
#   {'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 29,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 6.458936695707962e-06,
#     'Negative': 0.0033514259848743677,
#     'Neutral': 0.9078542590141296,
#     'Positive': 0.08878780156373978}},
#   {'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 30,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 3.1222823508869624e-06,
#     'Negative': 0.013366387225687504,
#     'Neutral': 0.9852913618087769,
#     'Positive': 0.0013390512904152274}},
#   {'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 31,
#    'Sentiment': 'NEGATIVE',
#    'SentimentScore': {'Mixed': 0.023822542279958725,
#     'Negative': 0.831144392490387,
#     'Neutral': 0.12617573142051697,
#     'Positive': 0.018857307732105255}},
#   {'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 34,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.00019462085037957877,
#     'Negative': 0.07877301424741745,
#     'Neutral': 0.8584991097450256,
#     'Positive': 0.06253322958946228}},
#   {'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 36,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.0006343146087601781,
#     'Negative': 0.07518170773983002,
#     'Neutral': 0.6052805781364441,
#     'Positive': 0.3189034163951874}},
#   {'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 7,
#    'Sentiment': 'POSITIVE',
#    'SentimentScore': {'Mixed': 3.5802142974716844e-06,
#     'Negative': 0.003000404220074415,
#     'Neutral': 0.36771953105926514,
#     'Positive': 0.6292765140533447}},
#   {'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 33,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 2.7113312626170227e-06,
#     'Negative': 0.0006556183798238635,
#     'Neutral': 0.9532630443572998,
#     'Positive': 0.046078622341156006}},
#   {'File': '00051_Peter_Martin_Wallis_Redacted.json',
#    'Line': 37,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 5.588323620031588e-05,
#     'Negative': 0.008859421126544476,
#     'Neutral': 0.8807646036148071,
#     'Positive': 0.11032017320394516}}],
#  '00055_Thomas_Kulpe_Redacted.json': [{'File': '00055_Thomas_Kulpe_Redacted.json',
#    'Line': 1,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00055_Thomas_Kulpe_Redacted.json',
#    'Line': 0,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 8.965320739662275e-05,
#     'Negative': 0.3067852258682251,
#     'Neutral': 0.6329675912857056,
#     'Positive': 0.060157597064971924}},
#   {'File': '00055_Thomas_Kulpe_Redacted.json',
#    'Line': 2,
#    'Sentiment': 'NEGATIVE',
#    'SentimentScore': {'Mixed': 0.00040485631325282156,
#     'Negative': 0.8073747754096985,
#     'Neutral': 0.1890600025653839,
#     'Positive': 0.0031603698153048754}},
#   {'File': '00055_Thomas_Kulpe_Redacted.json',
#    'Line': 4,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00055_Thomas_Kulpe_Redacted.json',
#    'Line': 5,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 1.1110975719930138e-05,
#     'Negative': 0.005887445528060198,
#     'Neutral': 0.9936216473579407,
#     'Positive': 0.00047975918278098106}},
#   {'File': '00055_Thomas_Kulpe_Redacted.json',
#    'Line': 3,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.0069609759375452995,
#     'Negative': 0.0618508905172348,
#     'Neutral': 0.6728278994560242,
#     'Positive': 0.2583602964878082}}],
#  '00054_John_Lawson_Redacted.json': [{'File': '00054_John_Lawson_Redacted.json',
#    'Line': 0,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.00020323917851783335,
#     'Negative': 0.1788017898797989,
#     'Neutral': 0.797350287437439,
#     'Positive': 0.023644711822271347}}],
#  '00057_Dan_McGuire_Redacted.json': [{'File': '00057_Dan_McGuire_Redacted.json',
#    'Line': 5,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00057_Dan_McGuire_Redacted.json',
#    'Line': 6,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 1.8416903913021088e-05,
#     'Negative': 0.07207851111888885,
#     'Neutral': 0.9273094534873962,
#     'Positive': 0.000593627686612308}},
#   {'File': '00057_Dan_McGuire_Redacted.json',
#    'Line': 0,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.0002950975322164595,
#     'Negative': 0.3484172821044922,
#     'Neutral': 0.5633020997047424,
#     'Positive': 0.08798549324274063}},
#   {'File': '00057_Dan_McGuire_Redacted.json',
#    'Line': 1,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.00010656661470420659,
#     'Negative': 0.24677549302577972,
#     'Neutral': 0.7345069050788879,
#     'Positive': 0.018611086532473564}},
#   {'File': '00057_Dan_McGuire_Redacted.json',
#    'Line': 2,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.00024351762840524316,
#     'Negative': 0.2292058765888214,
#     'Neutral': 0.7050198316574097,
#     'Positive': 0.06553076207637787}},
#   {'File': '00057_Dan_McGuire_Redacted.json',
#    'Line': 3,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.0001501283550169319,
#     'Negative': 0.01419643871486187,
#     'Neutral': 0.9831884503364563,
#     'Positive': 0.002465021563693881}},
#   {'File': '00057_Dan_McGuire_Redacted.json',
#    'Line': 4,
#    'Sentiment': 'NEGATIVE',
#    'SentimentScore': {'Mixed': 1.1032398106181063e-05,
#     'Negative': 0.9635739326477051,
#     'Neutral': 0.03496081009507179,
#     'Positive': 0.0014541976852342486}}],
#  '00059_Samuel_Redacted.json': [{'File': '00059_Samuel_Redacted.json',
#    'Line': 0,
#    'Sentiment': 'NEGATIVE',
#    'SentimentScore': {'Mixed': 1.2608124052349012e-05,
#     'Negative': 0.7543032765388489,
#     'Neutral': 0.06447170674800873,
#     'Positive': 0.18121246993541718}}],
#  '00062_George_Dewar_Redacted.json': [{'File': '00062_George_Dewar_Redacted.json',
#    'Line': 1,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00062_George_Dewar_Redacted.json',
#    'Line': 2,
#    'Sentiment': 'NEGATIVE',
#    'SentimentScore': {'Mixed': 0.0002771021972876042,
#     'Negative': 0.7943678498268127,
#     'Neutral': 0.12717914581298828,
#     'Positive': 0.07817588746547699}},
#   {'File': '00062_George_Dewar_Redacted.json',
#    'Line': 0,
#    'Sentiment': 'POSITIVE',
#    'SentimentScore': {'Mixed': 2.00509384740144e-06,
#     'Negative': 0.00010260941053275019,
#     'Neutral': 0.0020559749100357294,
#     'Positive': 0.9978393316268921}}],
#  '00063_Anonymous.json': [{'File': '00063_Anonymous.json',
#    'Line': 1,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00063_Anonymous.json',
#    'Line': 4,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00063_Anonymous.json',
#    'Line': 6,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00063_Anonymous.json',
#    'Line': 7,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00063_Anonymous.json',
#    'Line': 8,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00063_Anonymous.json',
#    'Line': 9,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00063_Anonymous.json',
#    'Line': 0,
#    'Sentiment': 'POSITIVE',
#    'SentimentScore': {'Mixed': 9.28285953705199e-05,
#     'Negative': 0.04242224618792534,
#     'Neutral': 0.4768260419368744,
#     'Positive': 0.4806588888168335}},
#   {'File': '00063_Anonymous.json',
#    'Line': 2,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 6.642685548285954e-06,
#     'Negative': 0.0012910198420286179,
#     'Neutral': 0.6717025637626648,
#     'Positive': 0.3269997239112854}},
#   {'File': '00063_Anonymous.json',
#    'Line': 3,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 7.8279217632371e-06,
#     'Negative': 0.003035002388060093,
#     'Neutral': 0.7856099605560303,
#     'Positive': 0.21134717762470245}},
#   {'File': '00063_Anonymous.json',
#    'Line': 5,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.0025924001820385456,
#     'Negative': 0.43662384152412415,
#     'Neutral': 0.5061416625976562,
#     'Positive': 0.05464202165603638}}],
#  '00066_Anonymous.json': [{'File': '00066_Anonymous.json',
#    'Line': 1,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00066_Anonymous.json',
#    'Line': 3,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00066_Anonymous.json',
#    'Line': 4,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00066_Anonymous.json',
#    'Line': 5,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00066_Anonymous.json',
#    'Line': 6,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00066_Anonymous.json',
#    'Line': 7,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00066_Anonymous.json',
#    'Line': 0,
#    'Sentiment': 'POSITIVE',
#    'SentimentScore': {'Mixed': 0.13662543892860413,
#     'Negative': 0.06186303123831749,
#     'Neutral': 0.035351403057575226,
#     'Positive': 0.7661601901054382}},
#   {'File': '00066_Anonymous.json',
#    'Line': 2,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 2.5793675376917236e-05,
#     'Negative': 0.02680247090756893,
#     'Neutral': 0.722991943359375,
#     'Positive': 0.25017979741096497}}],
#  '00068_Alun_Lloyd_Redacted.json': [{'File': '00068_Alun_Lloyd_Redacted.json',
#    'Line': 0,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 1.7374455637764186e-05,
#     'Negative': 0.3710152506828308,
#     'Neutral': 0.6226359605789185,
#     'Positive': 0.00633141677826643}}],
#  '00070_Wolf_Ammon_Redacted.json': [{'File': '00070_Wolf_Ammon_Redacted.json',
#    'Line': 1,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00070_Wolf_Ammon_Redacted.json',
#    'Line': 5,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00070_Wolf_Ammon_Redacted.json',
#    'Line': 8,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00070_Wolf_Ammon_Redacted.json',
#    'Line': 11,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '00070_Wolf_Ammon_Redacted.json',
#    'Line': 0,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 8.013789738470223e-06,
#     'Negative': 0.03193254396319389,
#     'Neutral': 0.8883339166641235,
#     'Positive': 0.079725481569767}},
#   {'File': '00070_Wolf_Ammon_Redacted.json',
#    'Line': 2,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 5.822952516609803e-06,
#     'Negative': 0.002153581939637661,
#     'Neutral': 0.9723766446113586,
#     'Positive': 0.02546389028429985}},
#   {'File': '00070_Wolf_Ammon_Redacted.json',
#    'Line': 4,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 8.05475610832218e-06,
#     'Negative': 0.0052676633931696415,
#     'Neutral': 0.884807825088501,
#     'Positive': 0.10991653054952621}},
#   {'File': '00070_Wolf_Ammon_Redacted.json',
#    'Line': 6,
# ...
#    'Line': 1,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '09575_Sharyn_Joy_Watkins_Redacted.json',
#    'Line': 4,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '09575_Sharyn_Joy_Watkins_Redacted.json',
#    'Line': 6,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.006186815444380045,
#     'Negative': 0.03696736693382263,
#     'Neutral': 0.9465543627738953,
#     'Positive': 0.010291509330272675}},
#   {'File': '09575_Sharyn_Joy_Watkins_Redacted.json',
#    'Line': 5,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 9.146900083578657e-06,
#     'Negative': 0.10079877823591232,
#     'Neutral': 0.8462159633636475,
#     'Positive': 0.05297606438398361}}],
#  '09457_Michael_Bell_Redacted.json': [{'File': '09457_Michael_Bell_Redacted.json',
#    'Line': 0,
#    'Sentiment': 'POSITIVE',
#    'SentimentScore': {'Mixed': 0.0028205416165292263,
#     'Negative': 0.01209518127143383,
#     'Neutral': 0.24846835434436798,
#     'Positive': 0.7366160154342651}}],
#  '09505_Rachel_Amanda_Felicia_Harvey-Lees-Green_Redacted.json': [{'File': '09505_Rachel_Amanda_Felicia_Harvey-Lees-Green_Redacted.json',
#    'Line': 0,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.00012945217895321548,
#     'Negative': 0.008766723796725273,
#     'Neutral': 0.8045384883880615,
#     'Positive': 0.1865653395652771}}],
#  '09586_Peter_Francis_Kerr_Redacted.json': [{'File': '09586_Peter_Francis_Kerr_Redacted.json',
#    'Line': 0,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 4.829043518839171e-06,
#     'Negative': 0.07184460014104843,
#     'Neutral': 0.9256356358528137,
#     'Positive': 0.0025149639695882797}}],
#  '09587_Simon_Williams_Redacted.json': [{'File': '09587_Simon_Williams_Redacted.json',
#    'Line': 3,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.0001635681401239708,
#     'Negative': 0.006668325047940016,
#     'Neutral': 0.8364328742027283,
#     'Positive': 0.15673528611660004}},
#   {'File': '09587_Simon_Williams_Redacted.json',
#    'Line': 1,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '09587_Simon_Williams_Redacted.json',
#    'Line': 4,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '09587_Simon_Williams_Redacted.json',
#    'Line': 0,
#    'Sentiment': 'POSITIVE',
#    'SentimentScore': {'Mixed': 4.9865506298374385e-05,
#     'Negative': 0.003268161555752158,
#     'Neutral': 0.37008798122406006,
#     'Positive': 0.6265939474105835}},
#   {'File': '09587_Simon_Williams_Redacted.json',
#    'Line': 2,
#    'Sentiment': 'MIXED',
#    'SentimentScore': {'Mixed': 0.6950405836105347,
#     'Negative': 0.01705012284219265,
#     'Neutral': 0.23534265160560608,
#     'Positive': 0.05256665498018265}},
#   {'File': '09587_Simon_Williams_Redacted.json',
#    'Line': 5,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 1.649469049880281e-05,
#     'Negative': 0.006893725600093603,
#     'Neutral': 0.959858238697052,
#     'Positive': 0.033231623470783234}}],
#  '09559_David_Broome_Redacted.json': [{'File': '09559_David_Broome_Redacted.json',
#    'Line': 0,
#    'Sentiment': 'NEGATIVE',
#    'SentimentScore': {'Mixed': 0.00013768489588983357,
#     'Negative': 0.9129224419593811,
#     'Neutral': 0.08493783324956894,
#     'Positive': 0.0020020410884171724}}],
#  '09577_Kevin_Wayne_Hall_Redacted.json': [{'File': '09577_Kevin_Wayne_Hall_Redacted.json',
#    'Line': 1,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '09577_Kevin_Wayne_Hall_Redacted.json',
#    'Line': 2,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 7.306660700123757e-05,
#     'Negative': 0.0015957988798618317,
#     'Neutral': 0.9847990870475769,
#     'Positive': 0.013532137498259544}},
#   {'File': '09577_Kevin_Wayne_Hall_Redacted.json',
#    'Line': 0,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.0001276300463359803,
#     'Negative': 0.3546240031719208,
#     'Neutral': 0.6386334300041199,
#     'Positive': 0.006614966318011284}}],
#  '09578_Bruce_Smith_Redacted.json': [{'File': '09578_Bruce_Smith_Redacted.json',
#    'Line': 0,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 5.729697477363516e-06,
#     'Negative': 0.000985664315521717,
#     'Neutral': 0.962080717086792,
#     'Positive': 0.03692789375782013}}],
#  '09615_Richard_Wayne_Cartwright_Redacted.json': [{'File': '09615_Richard_Wayne_Cartwright_Redacted.json',
#    'Line': 2,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '09615_Richard_Wayne_Cartwright_Redacted.json',
#    'Line': 0,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 3.311106638648198e-06,
#     'Negative': 0.001985755981877446,
#     'Neutral': 0.6180292963981628,
#     'Positive': 0.3799816071987152}},
#   {'File': '09615_Richard_Wayne_Cartwright_Redacted.json',
#    'Line': 1,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 1.306483568441763e-06,
#     'Negative': 0.0005510619375854731,
#     'Neutral': 0.9870259165763855,
#     'Positive': 0.012421735562384129}},
#   {'File': '09615_Richard_Wayne_Cartwright_Redacted.json',
#    'Line': 3,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 2.715684104259708e-06,
#     'Negative': 0.0018402017885819077,
#     'Neutral': 0.9804680347442627,
#     'Positive': 0.017689133062958717}}],
#  '09624_Anonymous.json': [{'File': '09624_Anonymous.json',
#    'Line': 2,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '09624_Anonymous.json',
#    'Line': 4,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '09624_Anonymous.json',
#    'Line': 5,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '09624_Anonymous.json',
#    'Line': 6,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '09624_Anonymous.json',
#    'Line': 7,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '09624_Anonymous.json',
#    'Line': 8,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '09624_Anonymous.json',
#    'Line': 1,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 2.8715239750454202e-05,
#     'Negative': 0.05034032091498375,
#     'Neutral': 0.8242475390434265,
#     'Positive': 0.1253833919763565}},
#   {'File': '09624_Anonymous.json',
#    'Line': 3,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 5.351119034457952e-05,
#     'Negative': 0.1743171066045761,
#     'Neutral': 0.7680352330207825,
#     'Positive': 0.05759422108530998}},
#   {'File': '09624_Anonymous.json',
#    'Line': 0,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 4.0138233998732176e-06,
#     'Negative': 0.0013477058382704854,
#     'Neutral': 0.6772804856300354,
#     'Positive': 0.3213677406311035}}],
#  '09643_Richard_Peter_Rothwell_Redacted.json': [{'File': '09643_Richard_Peter_Rothwell_Redacted.json',
#    'Line': 1,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '09643_Richard_Peter_Rothwell_Redacted.json',
#    'Line': 0,
#    'Sentiment': 'POSITIVE',
#    'SentimentScore': {'Mixed': 6.429194763768464e-05,
#     'Negative': 0.35954034328460693,
#     'Neutral': 0.1797640025615692,
#     'Positive': 0.46063128113746643}},
#   {'File': '09643_Richard_Peter_Rothwell_Redacted.json',
#    'Line': 2,
#    'Sentiment': 'NEGATIVE',
#    'SentimentScore': {'Mixed': 0.020131096243858337,
#     'Negative': 0.39839044213294983,
#     'Neutral': 0.2742130160331726,
#     'Positive': 0.30726534128189087}}],
#  '09673_Anonymous.json': [{'File': '09673_Anonymous.json',
#    'Line': 2,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '09673_Anonymous.json',
#    'Line': 3,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '09673_Anonymous.json',
#    'Line': 4,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '09673_Anonymous.json',
#    'Line': 5,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '09673_Anonymous.json',
#    'Line': 6,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '09673_Anonymous.json',
#    'Line': 0,
#    'Sentiment': 'NEGATIVE',
#    'SentimentScore': {'Mixed': 1.0481028311914997e-06,
#     'Negative': 0.8077985048294067,
#     'Neutral': 0.18972429633140564,
#     'Positive': 0.002476217458024621}},
#   {'File': '09673_Anonymous.json',
#    'Line': 1,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 2.1268240288918605e-06,
#     'Negative': 0.001241737394593656,
#     'Neutral': 0.9709798693656921,
#     'Positive': 0.0277763232588768}}],
#  '09679_Margaret_Susan_Baker_Redacted.json': [{'File': '09679_Margaret_Susan_Baker_Redacted.json',
#    'Line': 1,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '09679_Margaret_Susan_Baker_Redacted.json',
#    'Line': 0,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 5.055279325461015e-05,
#     'Negative': 0.3459189236164093,
#     'Neutral': 0.5798915028572083,
#     'Positive': 0.0741390734910965}},
#   {'File': '09679_Margaret_Susan_Baker_Redacted.json',
#    'Line': 2,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 4.216567504045088e-06,
#     'Negative': 0.001613460830412805,
#     'Neutral': 0.9743326902389526,
#     'Positive': 0.02404966950416565}}],
#  '09702_Theresa_Reid_Redacted.json': [{'File': '09702_Theresa_Reid_Redacted.json',
#    'Line': 0,
#    'Sentiment': 'POSITIVE',
#    'SentimentScore': {'Mixed': 2.1057708181615453e-06,
#     'Negative': 1.9847202565870248e-05,
#     'Neutral': 0.002826985903084278,
#     'Positive': 0.9971510767936707}}],
#  '09080_Marianne_Pettigrew_Redacted.json': [{'File': '09080_Marianne_Pettigrew_Redacted.json',
#    'Line': 0,
#    'Sentiment': 'NEGATIVE',
#    'SentimentScore': {'Mixed': 1.55921297846362e-05,
#     'Negative': 0.8009507060050964,
#     'Neutral': 0.1181458905339241,
#     'Positive': 0.08088788390159607}}],
#  '02115_Sarah_Guppy_Redacted.json': [{'File': '02115_Sarah_Guppy_Redacted.json',
#    'Line': 0,
#    'Sentiment': 'POSITIVE',
#    'SentimentScore': {'Mixed': 3.1423685868503526e-05,
#     'Negative': 0.23172667622566223,
#     'Neutral': 0.16622354090213776,
#     'Positive': 0.6020183563232422}}],
#  '09739_Anonymous.json': [{'File': '09739_Anonymous.json',
#    'Line': 4,
#    'Sentiment': 'POSITIVE',
#    'SentimentScore': {'Mixed': 5.38241547474172e-05,
#     'Negative': 0.07451408356428146,
#     'Neutral': 0.18150101602077484,
#     'Positive': 0.7439311146736145}},
#   {'File': '09739_Anonymous.json',
#    'Line': 0,
#    'Sentiment': 'NEGATIVE',
#    'SentimentScore': {'Mixed': 7.244533480843529e-05,
#     'Negative': 0.6853723526000977,
#     'Neutral': 0.2584860026836395,
#     'Positive': 0.056069258600473404}},
#   {'File': '09739_Anonymous.json',
#    'Line': 1,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 6.420534919016063e-05,
#     'Negative': 0.0636584535241127,
#     'Neutral': 0.7886894345283508,
#     'Positive': 0.147587850689888}},
#   {'File': '09739_Anonymous.json',
#    'Line': 2,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.0005435912171378732,
#     'Negative': 0.06197400763630867,
#     'Neutral': 0.815047562122345,
#     'Positive': 0.12243484705686569}},
#   {'File': '09739_Anonymous.json',
#    'Line': 3,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '09739_Anonymous.json',
#    'Line': 5,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 3.883981116814539e-05,
#     'Negative': 0.030766574665904045,
#     'Neutral': 0.9516141414642334,
#     'Positive': 0.017580546438694}},
#   {'File': '09739_Anonymous.json',
#    'Line': 6,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '09739_Anonymous.json',
#    'Line': 7,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '09739_Anonymous.json',
#    'Line': 8,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '09739_Anonymous.json',
#    'Line': 9,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}},
#   {'File': '09739_Anonymous.json',
#    'Line': 10,
#    'Sentiment': 'NEUTRAL',
#    'SentimentScore': {'Mixed': 0.015659846365451813,
#     'Negative': 0.019259486347436905,
#     'Neutral': 0.9320765733718872,
#     'Positive': 0.033004164695739746}}],
#  '09611_Jon_Brett_Redacted.json': [{'File': '09611_Jon_Brett_Redacted.json',
#    'Line': 0,
#    'Sentiment': 'NEGATIVE',
#    'SentimentScore': {'Mixed': 0.0035753699485212564,
#     'Negative': 0.5163655877113342,
#     'Neutral': 0.4778010845184326,
#     'Positive': 0.002257945481687784}}],
#  '2053_Ronald_Kevin_Low.json': [{'File': '2053_Ronald_Kevin_Low.json',
#    'Line': 0,
#    'Sentiment': 'NEGATIVE',
#    'SentimentScore': {'Mixed': 6.255716584746551e-07,
#     'Negative': 0.9975799322128296,
#     'Neutral': 0.0022808811627328396,
#     'Positive': 0.00013858440797775984}},
#   {'File': '2053_Ronald_Kevin_Low.json',
#    'Line': 1,
#    'Sentiment': 'NEGATIVE',
#    'SentimentScore': {'Mixed': 0.00010442327766213566,
#     'Negative': 0.8996983766555786,
#     'Neutral': 0.06248864904046059,
#     'Positive': 0.03770853951573372}}]}

# %%
import csv

docs_with_topics = {}

with open('zero-carbon-bill/topic-modelling/doc-topics.csv', newline='') as doc_topics:
    reader = csv.reader(doc_topics, delimiter=',')
    for row in reader:
        if row[0] == 'docname':
            next
        else:
            filename = row[0]
            item = {'topic': row[1], 'confidence': row[2]}
            
            if docs_with_topics.get(filename, None) is None:
                docs_with_topics[filename] = []
            docs_with_topics[filename].append(item)

docs_with_topics
# Out:
# {'09177_Janet_Marsh-Lord_Redacted.json': [{'topic': '017',
#    'confidence': '1.0'}],
#  '09523_Anonymous.json': [{'topic': '002', 'confidence': '1.0'}],
#  '09466_Andy_Eastcott_Redacted.json': [{'topic': '008',
#    'confidence': '1.0'}],
#  '01747_Graeme_Laws_Redacted.json': [{'topic': '003',
#    'confidence': '1.0'}],
#  '07981_Anonymous.json': [{'topic': '002', 'confidence': '1.0'}],
#  '08386_David_Yockney_Redacted.json': [{'topic': '003',
#    'confidence': '1.0'}],
#  '00662_Anne_Herrington_Redacted.json': [{'topic': '003',
#    'confidence': '1.0'}],
#  '01193_Jennifer_Ward_Redacted.json': [{'topic': '004',
#    'confidence': '1.0'}],
#  '09378_Margaret_Mollison_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '00136_Malcolm_Robert_Long_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '01907_Kathryn_Mercer_Redacted.json': [{'topic': '000',
#    'confidence': '0.814781'},
#   {'topic': '001', 'confidence': '0.185219'}],
#  '08601_Keith_Morfett_Redacted.json': [{'topic': '004',
#    'confidence': '1.0'}],
#  '09381_Anonymous.json': [{'topic': '002', 'confidence': '0.356181'},
#   {'topic': '000', 'confidence': '0.24606'},
#   {'topic': '001', 'confidence': '0.203966'},
#   {'topic': '008', 'confidence': '0.104877'},
#   {'topic': '017', 'confidence': '0.061602'},
#   {'topic': '006', 'confidence': '0.027314'}],
#  '02089_Camryn_Brown_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '09474_Anonymous.json': [{'topic': '004', 'confidence': '1.0'}],
#  '08337_William_Ernest_Gerring_Redacted.json': [{'topic': '004',
#    'confidence': '1.0'}],
#  '02080_Anonymous.json': [{'topic': '008', 'confidence': '1.0'}],
#  '09478_Samantha_Hoskins_Redacted.json': [{'topic': '003',
#    'confidence': '1.0'}],
#  '02096_Leonardus_Cornelis_Ratten_Redacted.json': [{'topic': '016',
#    'confidence': '1.0'}],
#  '02110_Anonymous.json': [{'topic': '002', 'confidence': '1.0'}],
#  '09702_Theresa_Reid_Redacted.json': [{'topic': '015',
#    'confidence': '1.0'}],
#  '09476_David_Stewart_Bull_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '00173_Phill_Round_Redacted.json': [{'topic': '013',
#    'confidence': '1.0'}],
#  '02088_Raymi_Hurtado-Stuart_Redacted.json': [{'topic': '006',
#    'confidence': '1.0'}],
#  '02078_Cavin_Shakesheave_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '09120_Neville_Baxter_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '01790_Alan_Willoughby_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '00132_Sieska_Verdonk_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '00245_Anonymous.json': [{'topic': '001', 'confidence': '1.0'}],
#  '00055_Thomas_Kulpe_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '00083_Anonymous.json': [{'topic': '003', 'confidence': '1.0'}],
#  '02632_Anonymous.json': [{'topic': '002', 'confidence': '0.344361'},
#   {'topic': '000', 'confidence': '0.142754'},
#   {'topic': '003', 'confidence': '0.114513'},
#   {'topic': '004', 'confidence': '0.107976'},
#   {'topic': '001', 'confidence': '0.084563'},
#   {'topic': '008', 'confidence': '0.079378'},
#   {'topic': '009', 'confidence': '0.038088'},
#   {'topic': '024', 'confidence': '0.026385'},
#   {'topic': '005', 'confidence': '0.025197'},
#   {'topic': '006', 'confidence': '0.017552'}],
#  '09372_Janet_Stephanie_Salas_Redacted.json': [{'topic': '008',
#    'confidence': '0.298453'},
#   {'topic': '002', 'confidence': '0.254657'},
#   {'topic': '000', 'confidence': '0.205625'},
#   {'topic': '001', 'confidence': '0.1822'},
#   {'topic': '003', 'confidence': '0.059066'}],
#  '05250_Anonymous.json': [{'topic': '001', 'confidence': '1.0'}],
#  '09539_Karen_Parr_Redacted.json': [{'topic': '000',
#    'confidence': '0.351015'},
#   {'topic': '001', 'confidence': '0.255679'},
#   {'topic': '002', 'confidence': '0.170722'},
#   {'topic': '005', 'confidence': '0.131839'},
#   {'topic': '003', 'confidence': '0.090745'}],
#  '09317_Anonymous.json': [{'topic': '001', 'confidence': '1.0'}],
#  '00009_Anonymous.json': [{'topic': '009', 'confidence': '1.0'}],
#  '02042_Anonymous.json': [{'topic': '000', 'confidence': '1.0'}],
#  '08207_Anonymous.json': [{'topic': '004', 'confidence': '1.0'}],
#  '02193_Anonymous.json': [{'topic': '000', 'confidence': '1.0'}],
#  '09441_Bronwyn_Judge_Redacted.json': [{'topic': '009',
#    'confidence': '1.0'}],
#  '02086_Annina_Ruegger_Redacted.json': [{'topic': '004',
#    'confidence': '1.0'}],
#  '07620_Ruth_Joiner_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '02119_David_Alexander_Simpson_Redacted.json': [{'topic': '019',
#    'confidence': '1.0'}],
#  '02331_Pat_Wall_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '01509_Adam_Weller_Redacted.json': [{'topic': '017',
#    'confidence': '1.0'}],
#  '09128_Dean_Campbell_Alexander_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '00145_Timothy_Andrew_Brake_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '03511_Johan_Willem_Laven_Redacted.json': [{'topic': '007',
#    'confidence': '1.0'}],
#  '00030_Anonymous.json': [{'topic': '001', 'confidence': '1.0'}],
#  '07163_Angela_Mary_McPherson_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '07702_Sean_Devine_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '00774_Anna_Schimmel_Redacted.json': [{'topic': '000',
#    'confidence': '0.814781'},
#   {'topic': '001', 'confidence': '0.185219'}],
#  '04079_Anonymous.json': [{'topic': '013', 'confidence': '1.0'}],
#  '01513_Anonymous.json': [{'topic': '000', 'confidence': '1.0'}],
#  '01545_Adrian_Reid_Redacted.json': [{'topic': '004',
#    'confidence': '1.0'}],
#  '09559_David_Broome_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '07724_Geoffrey_Ogilvie_Redacted.json': [{'topic': '005',
#    'confidence': '1.0'}],
#  '01276_Jacqueline_Anne_Tyrrell_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '08225_Jo_Wills_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '01074_Anonymous.json': [{'topic': '003', 'confidence': '1.0'}],
#  '07462_Anonymous.json': [{'topic': '000', 'confidence': '1.0'}],
#  '02115_Sarah_Guppy_Redacted.json': [{'topic': '004',
#    'confidence': '1.0'}],
#  '07078_Jon_Terry_Redacted.json': [{'topic': '005',
#    'confidence': '1.0'}],
#  '09574_Sharyn_Joy_Watkins_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '01063_Toby_Heale_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '00596_Anonymous.json': [{'topic': '000', 'confidence': '1.0'}],
#  '02020_William_Lionel_Hughes-Gamres_Redacted.json': [{'topic': '002',
#    'confidence': '0.302809'},
#   {'topic': '000', 'confidence': '0.296435'},
#   {'topic': '008', 'confidence': '0.154955'},
#   {'topic': '001', 'confidence': '0.087032'},
#   {'topic': '007', 'confidence': '0.044921'},
#   {'topic': '004', 'confidence': '0.041864'},
#   {'topic': '013', 'confidence': '0.035555'},
#   {'topic': '003', 'confidence': '0.020417'},
#   {'topic': '011', 'confidence': '0.016012'}],
#  '08220_Mark_Hooper_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '01282_Ian_Colin_Murphy_Redacted.json': [{'topic': '008',
#    'confidence': '0.348052'},
#   {'topic': '000', 'confidence': '0.283519'},
#   {'topic': '002', 'confidence': '0.26738'},
#   {'topic': '004', 'confidence': '0.101048'}],
#  '01312_William_Thorpe_Redacted.json': [{'topic': '005',
#    'confidence': '1.0'}],
#  '01169_Anonymous.json': [{'topic': '023', 'confidence': '1.0'}],
#  '01603_Raymond_Philip_Tremewan_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '09643_Richard_Peter_Rothwell_Redacted.json': [{'topic': '004',
#    'confidence': '1.0'}],
#  '00104_Wayne_Thomas_Sloane_Redacted.json': [{'topic': '003',
#    'confidence': '1.0'}],
#  '00406_Gary_Hayman_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '08364_Anthony_Armstrong.json': [{'topic': '013',
#    'confidence': '1.0'}],
#  '00140_Hadley_James_Kirkpatrick_Boyle_Redacted.json': [{'topic': '004',
#    'confidence': '1.0'}],
#  '02605_Wayne_Muntz_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '01763_Anonymous.json': [{'topic': '003', 'confidence': '1.0'}],
#  '01352_Anonymous.json': [{'topic': '000', 'confidence': '1.0'}],
#  '02161_Anonymous.json': [{'topic': '001', 'confidence': '1.0'}],
#  '09360_Maurice_James_Colgan_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '02064_Alan_Ian_Popay_Redacted.json': [{'topic': '008',
#    'confidence': '1.0'}],
#  '08415_Patricia_Anne_Nelson_Redacted.json': [{'topic': '018',
#    'confidence': '1.0'}],
#  '08024_Anonymous.json': [{'topic': '000', 'confidence': '1.0'}],
#  '08970_Richard_Edward_Green_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '09393_Anonymous.json': [{'topic': '008', 'confidence': '1.0'}],
#  '00585_Rosalia_A_M_Onderwater_Redacted.json': [{'topic': '011',
#    'confidence': '1.0'}],
#  '09446_Ottilie_Stolte_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '01392_Nicholas_John_Rountree_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '00651_Phillip_Schofield_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '01290_Lindsay_Brown_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '00689_Jude_De_Angulo_Redacted.json': [{'topic': '008',
#    'confidence': '1.0'}],
#  '00128_Anonymous.json': [{'topic': '002', 'confidence': '0.325338'},
#   {'topic': '000', 'confidence': '0.233955'},
#   {'topic': '004', 'confidence': '0.132558'},
#   {'topic': '008', 'confidence': '0.113946'},
#   {'topic': '001', 'confidence': '0.055074'},
#   {'topic': '006', 'confidence': '0.049937'},
#   {'topic': '027', 'confidence': '0.048948'},
#   {'topic': '017', 'confidence': '0.040244'}],
#  '09457_Michael_Bell_Redacted.json': [{'topic': '003',
#    'confidence': '1.0'}],
#  '00019_Linda_Bond_Redacted.json': [{'topic': '017',
#    'confidence': '1.0'}],
#  '01551_Anonymous.json': [{'topic': '000', 'confidence': '1.0'}],
#  '09554_Carla_Jehle_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '02583_Carol_Sutherland_Redacted.json': [{'topic': '002',
#    'confidence': '0.340038'},
#   {'topic': '001', 'confidence': '0.222892'},
#   {'topic': '000', 'confidence': '0.165696'},
#   {'topic': '008', 'confidence': '0.140523'},
#   {'topic': '004', 'confidence': '0.130852'}],
#  '09481_Terry_Drayton_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '00180_Anonymous.json': [{'topic': '008', 'confidence': '1.0'}],
#  '00740_William_Hambidge_Redacted.json': [{'topic': '002',
#    'confidence': '0.448344'},
#   {'topic': '008', 'confidence': '0.171286'},
#   {'topic': '000', 'confidence': '0.12243'},
#   {'topic': '004', 'confidence': '0.110566'},
#   {'topic': '001', 'confidence': '0.094709'},
#   {'topic': '013', 'confidence': '0.052665'}],
#  '09085_Stefanie_Gutschmidt_Redacted.json': [{'topic': '000',
#    'confidence': '0.814781'},
#   {'topic': '001', 'confidence': '0.185219'}],
#  '08265_Melissa_Redacted.json': [{'topic': '005',
#    'confidence': '1.0'}],
#  '06952_Yvonne_Ann_Curtis_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '02170_michael_jameson.json': [{'topic': '000', 'confidence': '1.0'}],
#  '01728_Karen_Titulaer_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '00155_David_Marriott_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '09528_April_Anne_Glenday_Redacted.json': [{'topic': '027',
#    'confidence': '1.0'}],
#  '00260_Anonymous.json': [{'topic': '000', 'confidence': '1.0'}],
#  '02118_Suzanne_Louise_Edmonds_Redacted.json': [{'topic': '008',
#    'confidence': '1.0'}],
#  '07272_Peter_Michael_Bacchus_Redacted.json': [{'topic': '004',
#    'confidence': '1.0'}],
#  '00875_Mark_Atkinson_Redacted.json': [{'topic': '013',
#    'confidence': '1.0'}],
#  '09251_Roger_William_Bent_Redacted.json': [{'topic': '002',
#    'confidence': '0.467506'},
#   {'topic': '000', 'confidence': '0.205848'},
#   {'topic': '008', 'confidence': '0.123539'},
#   {'topic': '001', 'confidence': '0.117373'},
#   {'topic': '020', 'confidence': '0.068733'},
#   {'topic': '005', 'confidence': '0.017001'}],
#  '01254_Kimbra_Taylor_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '02207_Anonymous.json': [{'topic': '013', 'confidence': '1.0'}],
#  '09101_Lan_Pham_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '02075_Helen_Linssen_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '09444_Liam_Matthew_Williams-Prince_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '09624_Anonymous.json': [{'topic': '008', 'confidence': '1.0'}],
#  '02057_Jacob_Redacted.json': [{'topic': '000',
#    'confidence': '0.814781'},
#   {'topic': '001', 'confidence': '0.185219'}],
#  '00601_Jonathan_Seymour_Dronfield_Redacted.json': [{'topic': '000',
#    'confidence': '0.293756'},
#   {'topic': '002', 'confidence': '0.246119'},
#   {'topic': '001', 'confidence': '0.217924'},
#   {'topic': '004', 'confidence': '0.102477'},
#   {'topic': '008', 'confidence': '0.081196'},
#   {'topic': '005', 'confidence': '0.032533'},
#   {'topic': '003', 'confidence': '0.025995'}],
#  '01686_Ronald_Bruce_MacDougall_Redacted.json': [{'topic': '002',
#    'confidence': '0.484835'},
#   {'topic': '004', 'confidence': '0.257004'},
#   {'topic': '000', 'confidence': '0.109691'},
#   {'topic': '001', 'confidence': '0.041113'},
#   {'topic': '009', 'confidence': '0.031052'},
#   {'topic': '013', 'confidence': '0.027632'},
#   {'topic': '017', 'confidence': '0.026486'},
#   {'topic': '007', 'confidence': '0.022186'}],
#  '01744_Rodney_Pilbrow_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '00099_Anonymous.json': [{'topic': '013', 'confidence': '1.0'}],
#  '00183_Shaun_Francis.json': [{'topic': '016', 'confidence': '1.0'}],
#  '02002_Nathan_Larry_Hills_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '2053_Ronald_Kevin_Low.json': [{'topic': '007', 'confidence': '1.0'}],
#  '09511_John_Adams_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '05266_Marcel_Currin_Redacted.json': [{'topic': '001',
#    'confidence': '0.513415'},
#   {'topic': '000', 'confidence': '0.342267'},
#   {'topic': '008', 'confidence': '0.099235'},
#   {'topic': '023', 'confidence': '0.045083'}],
#  '02091_Robert_Bingham_Redacted.json': [{'topic': '004',
#    'confidence': '1.0'}],
#  '09513_Rosalie_McIsaac_France_Redacted.json': [{'topic': '004',
#    'confidence': '1.0'}],
#  '09465_Patsy_Blackstock_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '00002_Jennifer_Valentine_Redacted.json': [{'topic': '006',
#    'confidence': '1.0'}],
#  '08308_Anonymous.json': [{'topic': '001', 'confidence': '1.0'}],
#  '01202_Anthony_Weddle_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '00056_David_Maclure_Redacted.json': [{'topic': '008',
#    'confidence': '1.0'}],
#  '00598_Julian_Seidenberg_Redacted.json': [{'topic': '013',
#    'confidence': '1.0'}],
#  '09445_Marcus_Simons_Redacted.json': [{'topic': '008',
#    'confidence': '1.0'}],
#  '02566_Peter_Carruthers_Redacted.json': [{'topic': '008',
#    'confidence': '0.27412'},
#   {'topic': '002', 'confidence': '0.230003'},
#   {'topic': '001', 'confidence': '0.213032'},
#   {'topic': '004', 'confidence': '0.175714'},
#   {'topic': '000', 'confidence': '0.107128'}],
#  '09573_Anonymous.json': [{'topic': '023', 'confidence': '1.0'}],
#  '01891_Randall_Cork_Redacted.json': [{'topic': '012',
#    'confidence': '1.0'}],
#  '00185_Anonymous.json': [{'topic': '000', 'confidence': '0.473535'},
#   {'topic': '002', 'confidence': '0.438037'},
#   {'topic': '004', 'confidence': '0.088428'}],
#  '00068_Alun_Lloyd_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '01305_William_Reaney_Redacted.json': [{'topic': '002',
#    'confidence': '0.343604'},
#   {'topic': '004', 'confidence': '0.271016'},
#   {'topic': '020', 'confidence': '0.14491'},
#   {'topic': '000', 'confidence': '0.141538'},
#   {'topic': '005', 'confidence': '0.098932'}],
#  '00717_Anonymous.json': [{'topic': '002', 'confidence': '1.0'}],
#  '01828_Stephanie_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '02539_Frank_James_McGuckian_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '00176_Anonymous.json': [{'topic': '000', 'confidence': '1.0'}],
#  '00119_Anonymous.json': [{'topic': '002', 'confidence': '1.0'}],
#  '00223_Oliver_Krollmann_Redacted.json': [{'topic': '015',
#    'confidence': '1.0'}],
#  '00149_Kerry_Jeanette_Tankard_Redacted.json': [{'topic': '023',
#    'confidence': '1.0'}],
#  '08858_David_Paul_Lawton_Redacted.json': [{'topic': '000',
#    'confidence': '0.814781'},
#   {'topic': '001', 'confidence': '0.185219'}],
#  '04999_Anonymous.json': [{'topic': '000', 'confidence': '1.0'}],
#  '00028_Daniel_Oades_Redacted.json': [{'topic': '022',
#    'confidence': '1.0'}],
#  '02572_Suzanne_Hills_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '07435_Anonymous.json': [{'topic': '004', 'confidence': '1.0'}],
#  '01760_Michael_Lloyd_Redacted.json': [{'topic': '000',
#    'confidence': '0.814781'},
#   {'topic': '001', 'confidence': '0.185219'}],
#  '02090_James_Arthur_Renwick_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '00181_Owen_Dyer_Redacted.json': [{'topic': '000',
#    'confidence': '0.814781'},
#   {'topic': '001', 'confidence': '0.185219'}],
#  '08978_V_Janne_Zabell_Redacted.json': [{'topic': '005',
#    'confidence': '1.0'}],
#  '02443_Anonymous.json': [{'topic': '002', 'confidence': '0.419124'},
#   {'topic': '008', 'confidence': '0.245419'},
#   {'topic': '000', 'confidence': '0.219512'},
#   {'topic': '004', 'confidence': '0.115944'}],
#  '02533_Anonymous.json': [{'topic': '000', 'confidence': '1.0'}],
#  '01190_Keith_Stewart_Redacted.json': [{'topic': '007',
#    'confidence': '1.0'}],
#  '02558_William_Van_Ausdal_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '09209_Jane_Powell_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '08927_Anonymous.json': [{'topic': '005', 'confidence': '1.0'}],
#  '08896_Robyn_Macleod_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '09023_Andrew_Barnes_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '01753_Kenneth_Greaves_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '00054_John_Lawson_Redacted.json': [{'topic': '014',
#    'confidence': '1.0'}],
#  '09095_Xavier_Serrallach_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '01082_Malcolm_White_Redacted.json': [{'topic': '020',
#    'confidence': '1.0'}],
#  '00023_Anonymous.json': [{'topic': '000', 'confidence': '1.0'}],
#  '01006_Anonymous.json': [{'topic': '000', 'confidence': '1.0'}],
#  '01018_Levonne_Smit_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '01191_David_Hodges_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '09587_Simon_Williams_Redacted.json': [{'topic': '008',
#    'confidence': '1.0'}],
#  '02636_Daphne_Bell_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '09180_John_Hollingsworth_Moore_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '09575_Sharyn_Joy_Watkins_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '09146_Antony_David_Gane_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '07630_Peter_John_Shand.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '01983_Olivier_Victor_Rochery_Redacted.json': [{'topic': '004',
#    'confidence': '1.0'}],
#  '09510_Lisa_Ellis_Redacted.json': [{'topic': '017',
#    'confidence': '1.0'}],
#  '08263_Pieter_van_Leeuwen_Redacted.json': [{'topic': '007',
#    'confidence': '1.0'}],
#  '09370_Anonymous.json': [{'topic': '001', 'confidence': '1.0'}],
#  '09350_Geoffrey_Ogilvie_Redacted.json': [{'topic': '004',
#    'confidence': '1.0'}],
#  '00657_Michael_Douglas_Scott_Redacted.json': [{'topic': '017',
#    'confidence': '1.0'}],
#  '01816_Anonymous.json': [{'topic': '004', 'confidence': '1.0'}],
#  '01496_Brent_Barrett_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '01875_Catherine_Doyle_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '01127_Glenn_Stewart_Redacted.json': [{'topic': '000',
#    'confidence': '0.344912'},
#   {'topic': '008', 'confidence': '0.286024'},
#   {'topic': '002', 'confidence': '0.19067'},
#   {'topic': '001', 'confidence': '0.101667'},
#   {'topic': '004', 'confidence': '0.076723'}],
#  '09507_Anonymous.json': [{'topic': '002', 'confidence': '1.0'}],
#  '02103_Anonymous.json': [{'topic': '008', 'confidence': '1.0'}],
#  '01532_Malcolm_Todd_Redacted.json': [{'topic': '008',
#    'confidence': '1.0'}],
#  '01745_David_Crook_Redacted.json': [{'topic': '008',
#    'confidence': '1.0'}],
#  '00628_Terry_Rozmus_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '07800_Fay_Brorens_Redacted.json': [{'topic': '009',
#    'confidence': '1.0'}],
#  '09347_Regan_Stokes_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '07270_Kathy_Gilbert_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '00076_Craig_Colton_Redacted.json': [{'topic': '008',
#    'confidence': '1.0'}],
#  '09497_Ulrike_Schamall_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '04266_Richard_Price_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '09526_Peter_Scott_Redacted.json': [{'topic': '004',
#    'confidence': '1.0'}],
#  '02568_Anonymous.json': [{'topic': '011', 'confidence': '1.0'}],
#  '09516_Gordon_Bruce_Tulloch_Redacted.json': [{'topic': '008',
#    'confidence': '1.0'}],
#  '01554_Lynette_Serjeant_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '01642_Anonymous.json': [{'topic': '016', 'confidence': '1.0'}],
#  '09149_Aileen_Redacted.json': [{'topic': '000', 'confidence': '1.0'}],
#  '02114_Alan_Barraclough_Redacted.json': [{'topic': '008',
#    'confidence': '1.0'}],
#  '05406_Brenda_Joan_Kaye_Redacted.json': [{'topic': '025',
#    'confidence': '1.0'}],
#  "09176_Leslie_John_O'Leary_Redacted.json": [{'topic': '000',
#    'confidence': '1.0'}],
#  '09388_Peter_John_Olorenshaw_Redacted.json': [{'topic': '002',
#    'confidence': '0.396039'},
#   {'topic': '000', 'confidence': '0.21284'},
#   {'topic': '008', 'confidence': '0.124375'},
#   {'topic': '020', 'confidence': '0.079049'},
#   {'topic': '013', 'confidence': '0.074059'},
#   {'topic': '004', 'confidence': '0.05576'},
#   {'topic': '001', 'confidence': '0.042302'},
#   {'topic': '024', 'confidence': '0.015576'}],
#  '09247_Darrell_Bathurst_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '00003_Siobhan_Lynch_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '07324_Anonymous.json': [{'topic': '015', 'confidence': '1.0'}],
#  '08990_Eion_Scott_Redacted.json': [{'topic': '002',
#    'confidence': '0.415982'},
#   {'topic': '000', 'confidence': '0.265446'},
#   {'topic': '007', 'confidence': '0.166972'},
#   {'topic': '001', 'confidence': '0.078104'},
#   {'topic': '008', 'confidence': '0.052625'},
#   {'topic': '016', 'confidence': '0.020871'}],
#  '09611_Jon_Brett_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '09097_Sam_Crawley_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '02559_Richard_Poynter_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '07271_Ewen_Cameron_Redacted.json': [{'topic': '013',
#    'confidence': '1.0'}],
#  '09080_Marianne_Pettigrew_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '05292_Anonymous.json': [{'topic': '000', 'confidence': '1.0'}],
#  '09198_Joseph_Anthony_Dougherty_Redacted.json': [{'topic': '000',
#    'confidence': '0.814781'},
#   {'topic': '001', 'confidence': '0.185219'}],
#  '00773_Laurie_Austen_Redacted.json': [{'topic': '008',
#    'confidence': '1.0'}],
#  '03007_Brett_Anthony_Keane_Redacted.json': [{'topic': '003',
#    'confidence': '1.0'}],
#  '01711_Anonymous.json': [{'topic': '023', 'confidence': '1.0'}],
#  '09178_David_Anthony_Francis_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '00190_Trish_Rankin_Redacted.json': [{'topic': '020',
#    'confidence': '1.0'}],
#  '08989_Mark_William_Bicknell_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '07793_Danny_Redacted.json': [{'topic': '011', 'confidence': '1.0'}],
#  '01564_Grace_Gillon_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '00177_Anonymous.json': [{'topic': '000', 'confidence': '1.0'}],
#  '00078_Dylan_Cliff_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '09524_Huia_Cameron_Jackson_Redacted.json': [{'topic': '000',
#    'confidence': '0.814781'},
#   {'topic': '001', 'confidence': '0.185219'}],
#  '09263_Michael_Godfrey_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '01777_Richard_James_Maher_Redacted.json': [{'topic': '004',
#    'confidence': '1.0'}],
#  '09615_Richard_Wayne_Cartwright_Redacted.json': [{'topic': '009',
#    'confidence': '1.0'}],
#  '00725_Barry_Reginald_Phease_Redacted.json': [{'topic': '003',
#    'confidence': '1.0'}],
#  '08351_Greg_Fisher_Redacted.json': [{'topic': '007',
#    'confidence': '1.0'}],
#  '02591_Richard_Sidney_Hovey_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '00050_Paul_Judge_Redacted.json': [{'topic': '008',
#    'confidence': '1.0'}],
#  '02367_Philip_John_Brimacombe_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '03863_Dharan_Longley_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '02125_Jenny_Easton_Redacted.json': [{'topic': '003',
#    'confidence': '1.0'}],
#  '09172_Patrick_Morgan_Redacted.json': [{'topic': '012',
#    'confidence': '1.0'}],
#  '09283_Anonymous.json': [{'topic': '023', 'confidence': '1.0'}],
#  '00014_Mike_Gwyther_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '00735_Konrad_Paul_Hickson_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '02511_Barry_Edward_Brill_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '01775_Raymond_John_Henderson_Redacted.json': [{'topic': '002',
#    'confidence': '0.356371'},
#   {'topic': '008', 'confidence': '0.190307'},
#   {'topic': '004', 'confidence': '0.157716'},
#   {'topic': '000', 'confidence': '0.146198'},
#   {'topic': '024', 'confidence': '0.057256'},
#   {'topic': '016', 'confidence': '0.038985'},
#   {'topic': '005', 'confidence': '0.032181'},
#   {'topic': '013', 'confidence': '0.020986'}],
#  '00059_Samuel_Redacted.json': [{'topic': '002', 'confidence': '1.0'}],
#  '01796_Anthony_Farrell_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '02444_Juhi_Shareef_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '07945_Chris_Cameron_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '02540_Jennifer_Dymock_Redacted.json': [{'topic': '008',
#    'confidence': '1.0'}],
#  '09673_Anonymous.json': [{'topic': '023', 'confidence': '1.0'}],
#  '01889_Vaughan_McCurrie_Redacted.json': [{'topic': '008',
#    'confidence': '1.0'}],
#  '02308_Alastair_Taylor_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '05950_Noel_J_Peterson_Redacted.json': [{'topic': '024',
#    'confidence': '1.0'}],
#  '01149_Anonymous.json': [{'topic': '000', 'confidence': '0.396922'},
#   {'topic': '002', 'confidence': '0.234878'},
#   {'topic': '020', 'confidence': '0.234147'},
#   {'topic': '001', 'confidence': '0.095844'},
#   {'topic': '004', 'confidence': '0.038209'}],
#  '01404_Deborah_Robb_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '00643_Victoria_Threadwell_Redacted.json': [{'topic': '002',
#    'confidence': '0.324858'},
#   {'topic': '000', 'confidence': '0.286003'},
#   {'topic': '007', 'confidence': '0.172552'},
#   {'topic': '004', 'confidence': '0.132878'},
#   {'topic': '008', 'confidence': '0.083709'}],
#  '02178_Duncan_Brown_Redacted.json': [{'topic': '002',
#    'confidence': '0.49302'},
#   {'topic': '000', 'confidence': '0.246442'},
#   {'topic': '005', 'confidence': '0.148158'},
#   {'topic': '009', 'confidence': '0.060819'},
#   {'topic': '008', 'confidence': '0.051562'}],
#  '09105_Helen_Patricia_Smith_Redacted.json': [{'topic': '000',
#    'confidence': '0.814781'},
#   {'topic': '001', 'confidence': '0.185219'}],
#  '01139_Anonymous.json': [{'topic': '000', 'confidence': '0.247602'},
#   {'topic': '002', 'confidence': '0.215122'},
#   {'topic': '004', 'confidence': '0.164025'},
#   {'topic': '008', 'confidence': '0.1385'},
#   {'topic': '001', 'confidence': '0.134276'},
#   {'topic': '014', 'confidence': '0.042714'},
#   {'topic': '024', 'confidence': '0.042614'},
#   {'topic': '016', 'confidence': '0.015147'}],
#  '00153_Anonymous.json': [{'topic': '000', 'confidence': '1.0'}],
#  "04461_Siobhan_O'Malley.json": [{'topic': '002',
#    'confidence': '0.370566'},
#   {'topic': '000', 'confidence': '0.273395'},
#   {'topic': '008', 'confidence': '0.100427'},
#   {'topic': '001', 'confidence': '0.080589'},
#   {'topic': '004', 'confidence': '0.064903'},
#   {'topic': '016', 'confidence': '0.064336'},
#   {'topic': '020', 'confidence': '0.029873'},
#   {'topic': '017', 'confidence': '0.01591'}],
#  '00004_Anonymous.json': [{'topic': '002', 'confidence': '1.0'}],
#  '00142_Matthew_Weir_Redacted.json': [{'topic': '013',
#    'confidence': '1.0'}],
#  '07269_Anonymous.json': [{'topic': '000', 'confidence': '0.360827'},
#   {'topic': '002', 'confidence': '0.282238'},
#   {'topic': '020', 'confidence': '0.185357'},
#   {'topic': '008', 'confidence': '0.140707'},
#   {'topic': '005', 'confidence': '0.030871'}],
#  '05187_Jeremie_Madamour_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '09203_Dinah_Sally_Hawken_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '08277_Anonymous.json': [{'topic': '011', 'confidence': '1.0'}],
#  '09281_Joanne_Elizabeth_McWilliam_Redacted.json': [{'topic': '003',
#    'confidence': '1.0'}],
#  '00574_Hilde_Krollmann_Redacted.json': [{'topic': '015',
#    'confidence': '1.0'}],
#  '09310_Michael_Bruce_Robertshawe_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '09479_Gregory_Bodeker_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '00193_Daniel_Francis_Mcphee_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '00653_John_Boon_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '00617_Susan_Lee_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '01898_Eileen_Hilda_Wright_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '09578_Bruce_Smith_Redacted.json': [{'topic': '000',
#    'confidence': '0.814781'},
#   {'topic': '001', 'confidence': '0.185219'}],
#  '09238_Liam_McIver_Redacted.json': [{'topic': '003',
#    'confidence': '1.0'}],
#  '00102_Peter_King_Redacted.json': [{'topic': '000',
#    'confidence': '0.355789'},
#   {'topic': '004', 'confidence': '0.175438'},
#   {'topic': '002', 'confidence': '0.140437'},
#   {'topic': '008', 'confidence': '0.13731'},
#   {'topic': '001', 'confidence': '0.092245'},
#   {'topic': '019', 'confidence': '0.04292'},
#   {'topic': '010', 'confidence': '0.034894'},
#   {'topic': '016', 'confidence': '0.020968'}],
#  '05461_Eileen_Wright.json': [{'topic': '004', 'confidence': '1.0'}],
#  '00147_Anonymous.json': [{'topic': '008', 'confidence': '1.0'}],
#  '01953_David_and_Sheryl_Tapp_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '00051_Peter_Martin_Wallis_Redacted.json': [{'topic': '002',
#    'confidence': '0.370706'},
#   {'topic': '008', 'confidence': '0.200134'},
#   {'topic': '000', 'confidence': '0.157827'},
#   {'topic': '004', 'confidence': '0.109055'},
#   {'topic': '001', 'confidence': '0.059849'},
#   {'topic': '003', 'confidence': '0.038716'},
#   {'topic': '013', 'confidence': '0.025569'},
#   {'topic': '009', 'confidence': '0.019245'},
#   {'topic': '016', 'confidence': '0.018897'}],
#  '00633_Anonymous.json': [{'topic': '023', 'confidence': '1.0'}],
#  '00154_Hazel_Margaret_Oldham_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '01476_David_Smiler_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '01589_Bruce_Martin_Redacted.json': [{'topic': '013',
#    'confidence': '1.0'}],
#  '02116_Beverley_Trowbridge_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '01885_Danny_Beskalo_Redacted.json': [{'topic': '008',
#    'confidence': '1.0'}],
#  '00770_Anonymous.json': [{'topic': '000', 'confidence': '1.0'}],
#  '01748_Anonymous.json': [{'topic': '000', 'confidence': '1.0'}],
#  '09334_Lindsey_Jones_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '01525_Keith_Douglas_Hitchon.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '07747_Helen_Elizabeth_McCormick_Redacted.json': [{'topic': '008',
#    'confidence': '1.0'}],
#  '08451_Carolyne_Latham_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '02604_Wayne_Muntz_Redacted.json': [{'topic': '024',
#    'confidence': '1.0'}],
#  '09493_Garry_David_Kyle_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '01560_Anonymous.json': [{'topic': '008', 'confidence': '1.0'}],
#  '00458_Grant_William_Bruce_Redacted.json': [{'topic': '004',
#    'confidence': '1.0'}],
#  '08322_Terry_McAtamney.json': [{'topic': '002', 'confidence': '1.0'}],
#  '09025_Brooke_La_Grouw_Redacted.json': [{'topic': '008',
#    'confidence': '1.0'}],
#  '04947_Daniel_Weinholz_Redacted.json': [{'topic': '007',
#    'confidence': '1.0'}],
#  '05227_Anonymous.json': [{'topic': '002', 'confidence': '1.0'}],
#  '04920_Anonymous.json': [{'topic': '001', 'confidence': '1.0'}],
#  '01880_Bryan_Trevor_Clements_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '00977_David_James_Riddell_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '08865_Cornelius_Beentjes_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '02194_Lauchlan_Grant_Duff_Redacted.json': [{'topic': '000',
#    'confidence': '0.814781'},
#   {'topic': '001', 'confidence': '0.185219'}],
#  '01241_Kim_Eros_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '07593_Anonymous.json': [{'topic': '000', 'confidence': '1.0'}],
#  '07232_Campbell_Knox.json': [{'topic': '000', 'confidence': '1.0'}],
#  '01779_Anonymous.json': [{'topic': '001', 'confidence': '1.0'}],
#  '00214_Anonymous.json': [{'topic': '024', 'confidence': '1.0'}],
#  '09496_Anonymous.json': [{'topic': '000', 'confidence': '1.0'}],
#  '01621_Jonathan_Philip_Harry_Taylor_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '01208_James_Edgar_Dent_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '00057_Dan_McGuire_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '09194_Peter_Schmuck-Poschl_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '02500_Cathryn_Faulkner_Redacted.json': [{'topic': '024',
#    'confidence': '1.0'}],
#  '03027_Jose_Luis_Gay_Cano_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '00935_Maxine_Mary_Campbell_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '01799_Francis_Sharp_Redacted.json': [{'topic': '007',
#    'confidence': '1.0'}],
#  '01922_Joanna_Santa_Barbara_Redacted.json': [{'topic': '008',
#    'confidence': '1.0'}],
#  '01773_Grant_Michael_Hammond_Redacted.json': [{'topic': '004',
#    'confidence': '1.0'}],
#  '02783_Matthew_Lambourn_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '00063_Anonymous.json': [{'topic': '002', 'confidence': '1.0'}],
#  '00631_Simon_Allen_Redacted.json': [{'topic': '024',
#    'confidence': '1.0'}],
#  '05204_Anonymous.json': [{'topic': '001', 'confidence': '0.507998'},
#   {'topic': '008', 'confidence': '0.219301'},
#   {'topic': '000', 'confidence': '0.17754'},
#   {'topic': '005', 'confidence': '0.095161'}],
#  '09369_Graeme_Ball_Redacted.json': [{'topic': '010',
#    'confidence': '1.0'}],
#  '04923_Anonymous.json': [{'topic': '002', 'confidence': '1.0'}],
#  '00034_Anonymous.json': [{'topic': '000', 'confidence': '1.0'}],
#  '00913_Anonymous.json': [{'topic': '009', 'confidence': '1.0'}],
#  '01756_Ross_Nixon_Redacted.json': [{'topic': '003',
#    'confidence': '1.0'}],
#  '02079_Andrew_McPherson_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '04805_Reuben_Cohen_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '00256_Hayley_Armstrong_Redacted.json': [{'topic': '017',
#    'confidence': '1.0'}],
#  '00013_Alice_Taylor_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '00138_Anonymous.json': [{'topic': '000', 'confidence': '0.814781'},
#   {'topic': '001', 'confidence': '0.185219'}],
#  '09490_Martin_Evans_Redacted.json': [{'topic': '025',
#    'confidence': '1.0'}],
#  '09017_Hugh_Loughnan_Redacted.json': [{'topic': '028',
#    'confidence': '1.0'}],
#  '01300_Isaac_Jonathan_Freeman_Redacted.json': [{'topic': '008',
#    'confidence': '1.0'}],
#  '08152_Andrew_William_Jefferies_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '09087_Karen_Dianne_Brookes_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '09285_Anonymous.json': [{'topic': '000', 'confidence': '0.399258'},
#   {'topic': '002', 'confidence': '0.244352'},
#   {'topic': '001', 'confidence': '0.11692'},
#   {'topic': '008', 'confidence': '0.079482'},
#   {'topic': '005', 'confidence': '0.047727'},
#   {'topic': '009', 'confidence': '0.043258'},
#   {'topic': '006', 'confidence': '0.034598'},
#   {'topic': '017', 'confidence': '0.034406'}],
#  '00583_Anna_Dobson_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '07921_Neil_Walbran_Redacted.json': [{'topic': '008',
#    'confidence': '1.0'}],
#  '07706_Anake_Goodall_Redacted.json': [{'topic': '019',
#    'confidence': '1.0'}],
#  '01492_Rebecca_Redacted.json': [{'topic': '000',
#    'confidence': '0.814781'},
#   {'topic': '001', 'confidence': '0.185219'}],
#  '01908_Philip_Marten_Turner_Redacted.json': [{'topic': '004',
#    'confidence': '1.0'}],
#  '00191_Alister_Ian_Gardiner_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '09382_Anonymous.json': [{'topic': '000', 'confidence': '0.275721'},
#   {'topic': '002', 'confidence': '0.255949'},
#   {'topic': '001', 'confidence': '0.167242'},
#   {'topic': '004', 'confidence': '0.158856'},
#   {'topic': '008', 'confidence': '0.061364'},
#   {'topic': '025', 'confidence': '0.04565'},
#   {'topic': '013', 'confidence': '0.035218'}],
#  '01807_Neil_Williams_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '08879_Guy_Wellwood_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '08972_Aidan_Bichan_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '01979_Annie_Cao_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '03113_Linda_Hill_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '02382_David_John_Mackenzie_Crabb_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '01607_Anonymous.json': [{'topic': '004', 'confidence': '1.0'}],
#  '06504_Elisabetta_Redacted.json': [{'topic': '017',
#    'confidence': '1.0'}],
#  '00031_Anne_Smith_Redacted.json': [{'topic': '008',
#    'confidence': '1.0'}],
#  '02534_Dell_McLeod_Redacted.json': [{'topic': '004',
#    'confidence': '1.0'}],
#  '01612_Tony_Veitch_Redacted.json': [{'topic': '010',
#    'confidence': '1.0'}],
#  '00184_Mere_Kepa_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '07651_Larry_Blair_Redacted.json': [{'topic': '009',
#    'confidence': '1.0'}],
#  '00137_Troy_Titheridge_Redacted.json': [{'topic': '013',
#    'confidence': '1.0'}],
#  '01204_Anonymous.json': [{'topic': '020', 'confidence': '1.0'}],
#  '00164_Kate_Scanlen_Redacted.json': [{'topic': '001',
#    'confidence': '0.422585'},
#   {'topic': '000', 'confidence': '0.294925'},
#   {'topic': '002', 'confidence': '0.140923'},
#   {'topic': '012', 'confidence': '0.07961'},
#   {'topic': '003', 'confidence': '0.061956'}],
#  '09163_Kevin_Andrew_Muir_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '00033_Ben_Mansfield_Redacted.json': [{'topic': '025',
#    'confidence': '1.0'}],
#  '02050_Margaret_Pearl_Redacted.json': [{'topic': '018',
#    'confidence': '1.0'}],
#  '02620_Fergus_Alexander_McCool_Redacted.json': [{'topic': '002',
#    'confidence': '0.638608'},
#   {'topic': '020', 'confidence': '0.361392'}],
#  '07823_Mike_Harvey_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '00074_George_Henderson_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '09340_Anonymous.json': [{'topic': '004', 'confidence': '1.0'}],
#  '08290_John_Hughlings_Jackson_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '00064_Murray_Hancock_Redacted.json': [{'topic': '004',
#    'confidence': '1.0'}],
#  '01829_Anonymous.json': [{'topic': '002', 'confidence': '1.0'}],
#  '02567_Mark_Drinkwater_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '07973_Christopher_Williams_Redacted.json': [{'topic': '005',
#    'confidence': '1.0'}],
#  '09461_Denis_Tegg_Redacted.json': [{'topic': '005',
#    'confidence': '1.0'}],
#  '07638_Cameron_Forbes.json': [{'topic': '004', 'confidence': '1.0'}],
#  '09525_Mark_Smith_Redacted.json': [{'topic': '002',
#    'confidence': '0.568761'},
#   {'topic': '001', 'confidence': '0.201711'},
#   {'topic': '008', 'confidence': '0.168917'},
#   {'topic': '006', 'confidence': '0.060611'}],
#  '00039_Ant_Wild_Redacted.json': [{'topic': '004',
#    'confidence': '1.0'}],
#  '02523_Alison_Burt.json': [{'topic': '000', 'confidence': '1.0'}],
#  '00062_George_Dewar_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '09421_Lynette_Elizabeth_Ross_Redacted.json': [{'topic': '005',
#    'confidence': '1.0'}],
#  '02407_Anonymous.json': [{'topic': '002', 'confidence': '1.0'}],
#  '01613_Gillian_Ward_Redacted.json': [{'topic': '009',
#    'confidence': '1.0'}],
#  '01931_Richard_N_Mitchell-Lowe_Redacted.json': [{'topic': '001',
#    'confidence': '0.248676'},
#   {'topic': '008', 'confidence': '0.192224'},
#   {'topic': '002', 'confidence': '0.169005'},
#   {'topic': '000', 'confidence': '0.142959'},
#   {'topic': '004', 'confidence': '0.109693'},
#   {'topic': '016', 'confidence': '0.068428'},
#   {'topic': '005', 'confidence': '0.039639'},
#   {'topic': '025', 'confidence': '0.029376'}],
#  '02084_James_Duncan_Booth_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '02561_Ashley_Noel_Hinton_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '02059_Katerina_Zuzanna_Seligman_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '01113_Marvin_Hubbard_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '09256_Anonymous.json': [{'topic': '023', 'confidence': '1.0'}],
#  '02133_Derek_John_Hall_Redacted.json': [{'topic': '003',
#    'confidence': '1.0'}],
#  '08109_Caroline_Syddall_Redacted.json': [{'topic': '021',
#    'confidence': '1.0'}],
#  '02026_Anonymous.json': [{'topic': '000', 'confidence': '0.301877'},
#   {'topic': '002', 'confidence': '0.248962'},
#   {'topic': '001', 'confidence': '0.177365'},
#   {'topic': '008', 'confidence': '0.118445'},
#   {'topic': '003', 'confidence': '0.101641'},
#   {'topic': '013', 'confidence': '0.030809'},
#   {'topic': '005', 'confidence': '0.020903'}],
#  '08293_Richard_James_Strutehers_Redacted.json': [{'topic': '019',
#    'confidence': '1.0'}],
#  '08920_Leslie_Wilson_Jones_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '07769_Thomas_Cantlon_Redacted.json': [{'topic': '020',
#    'confidence': '1.0'}],
#  '00213_Anonymous.json': [{'topic': '001', 'confidence': '1.0'}],
#  '02072_George_Wilder_Moss_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '02560_Jessika_Rosado_Redacted.json': [{'topic': '004',
#    'confidence': '1.0'}],
#  '00151_Anonymous.json': [{'topic': '006', 'confidence': '1.0'}],
#  '01213_George_Williams_Redacted.json': [{'topic': '028',
#    'confidence': '1.0'}],
#  '08863_Peter_Lindsay_Pascoe_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '08046_Mark_Walkington.json': [{'topic': '002',
#    'confidence': '0.303307'},
#   {'topic': '000', 'confidence': '0.227948'},
#   {'topic': '001', 'confidence': '0.156522'},
#   {'topic': '003', 'confidence': '0.131664'},
#   {'topic': '005', 'confidence': '0.072402'},
#   {'topic': '004', 'confidence': '0.060206'},
#   {'topic': '008', 'confidence': '0.047951'}],
#  '01743_Matthew_Newman_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '00578_Anonymous.json': [{'topic': '000', 'confidence': '0.814781'},
#   {'topic': '001', 'confidence': '0.185219'}],
#  '01815_Ian_Johnstone_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '01486_Anonymous.json': [{'topic': '001', 'confidence': '1.0'}],
#  '00134_Anonymous.json': [{'topic': '023', 'confidence': '1.0'}],
#  '03075_Anonymous.json': [{'topic': '000', 'confidence': '1.0'}],
#  '09417_Andrew_Mock_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '02052_Emma_Susan_Koch_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '08938_John_ONeill_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '00106_Mark_Hutt_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '00089_Jenny_Ritchie_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '02554_Thomas_Brian_Minns_Redacted.json': [{'topic': '024',
#    'confidence': '1.0'}],
#  '02637_Olivia_Elizabeth_Teryle_Yates_Redacted.json': [{'topic': '005',
#    'confidence': '1.0'}],
#  '01014_Sally_Prebble_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '06360_Christian_Leonard_Williams_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '08271_Geoff_and_Cath_Jopp.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '09460_Ursula_Patricia_Stuart_Brown_Redacted.json': [{'topic': '024',
#    'confidence': '1.0'}],
#  '02564_Peter_Carruthers_Redacted.json': [{'topic': '008',
#    'confidence': '0.27412'},
#   {'topic': '002', 'confidence': '0.230003'},
#   {'topic': '001', 'confidence': '0.213032'},
#   {'topic': '004', 'confidence': '0.175714'},
#   {'topic': '000', 'confidence': '0.107128'}],
#  '09550_Munendra_Nilesh_Narayan_Redacted.json': [{'topic': '012',
#    'confidence': '1.0'}],
#  '01630_Alec_Messenger_Redacted.json': [{'topic': '028',
#    'confidence': '1.0'}],
#  '08267_Hamish_Bielski.json': [{'topic': '004', 'confidence': '1.0'}],
#  '02476_Allan_Francis_Ross_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '08200_Anonymous.json': [{'topic': '006', 'confidence': '1.0'}],
#  '07599_Jo_Ann_Firestone_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '05336_Rand_Huso_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '00221_Robert_Bruce_Coleman_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '01455_Anonymous.json': [{'topic': '009', 'confidence': '1.0'}],
#  '02183_Anonymous.json': [{'topic': '028', 'confidence': '1.0'}],
#  '01090_Anonymous.json': [{'topic': '002', 'confidence': '1.0'}],
#  '01881_Fraser_Mcrae_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '00609_Hadley_Fierlinger_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '02093_Adam_Vincent_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '00032_Richard_Blair_Laurenson_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '00070_Wolf_Ammon_Redacted.json': [{'topic': '004',
#    'confidence': '1.0'}],
#  '09207_Christopher_Hugh_Naylor_Redacted.json': [{'topic': '013',
#    'confidence': '1.0'}],
#  '00139_Hadyn_James_Redacted.json': [{'topic': '008',
#    'confidence': '1.0'}],
#  '00665_Scott_Hindman_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '01703_John_Church_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '00143_Stephen_Christie_Redacted.json': [{'topic': '008',
#    'confidence': '1.0'}],
#  '01768_Heather_Hapeta_Redacted.json': [{'topic': '003',
#    'confidence': '1.0'}],
#  '00001_Deborah_Hide-Bayne_Redacted.json': [{'topic': '004',
#    'confidence': '1.0'}],
#  '09468_Mayan_Willow_Schraders_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '01971_Daniel_Joseph_Spinks_Redacted.json': [{'topic': '002',
#    'confidence': '0.475624'},
#   {'topic': '004', 'confidence': '0.155306'},
#   {'topic': '020', 'confidence': '0.147159'},
#   {'topic': '008', 'confidence': '0.125463'},
#   {'topic': '000', 'confidence': '0.096448'}],
#  '00018_Leigh_Nicholson_Redacted.json': [{'topic': '015',
#    'confidence': '1.0'}],
#  '02427_Terrry_Bunn_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '09495_Anonymous.json': [{'topic': '000', 'confidence': '0.471198'},
#   {'topic': '001', 'confidence': '0.191828'},
#   {'topic': '002', 'confidence': '0.146751'},
#   {'topic': '025', 'confidence': '0.100992'},
#   {'topic': '008', 'confidence': '0.089231'}],
#  '09359_Megan_Evans_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '01632_Anonymous.json': [{'topic': '004', 'confidence': '1.0'}],
#  '01334_Anonymous.json': [{'topic': '000', 'confidence': '1.0'}],
#  '09344_Trevor_Denis_Nugent_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '09091_Susan_Ellanora_Everitt_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '07980_Simon_Shaw_Redacted.json': [{'topic': '003',
#    'confidence': '1.0'}],
#  '08396_William_Teil_Partridge_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '01772_Dennis_Smith_Redacted.json': [{'topic': '008',
#    'confidence': '1.0'}],
#  '02137_Ian_Grant_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '01802_Jo_Holsted_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '00041_Anonymous.json': [{'topic': '002', 'confidence': '1.0'}],
#  '09313_Sarah_Granich_Redacted.json': [{'topic': '003',
#    'confidence': '1.0'}],
#  '08081_Grace_Catley_Redacted.json': [{'topic': '009',
#    'confidence': '1.0'}],
#  '02622_Jean_Anne_Rodgers_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '09168_Pippa_Cubey_Redacted.json': [{'topic': '008',
#    'confidence': '1.0'}],
#  '05764_John_McKinnon_Redacted.json': [{'topic': '004',
#    'confidence': '1.0'}],
#  '02596_Bruce_Justin_Chippindale_Redacted.json': [{'topic': '008',
#    'confidence': '0.191458'},
#   {'topic': '004', 'confidence': '0.186336'},
#   {'topic': '000', 'confidence': '0.163863'},
#   {'topic': '001', 'confidence': '0.132799'},
#   {'topic': '002', 'confidence': '0.127771'},
#   {'topic': '024', 'confidence': '0.093609'},
#   {'topic': '003', 'confidence': '0.0829'},
#   {'topic': '016', 'confidence': '0.021265'}],
#  '08219_Anonymous.json': [{'topic': '000', 'confidence': '0.365186'},
#   {'topic': '002', 'confidence': '0.171475'},
#   {'topic': '005', 'confidence': '0.097584'},
#   {'topic': '003', 'confidence': '0.086085'},
#   {'topic': '004', 'confidence': '0.082324'},
#   {'topic': '017', 'confidence': '0.077184'},
#   {'topic': '001', 'confidence': '0.072159'},
#   {'topic': '028', 'confidence': '0.048003'}],
#  '03223_Anonymous.json': [{'topic': '023', 'confidence': '1.0'}],
#  '09577_Kevin_Wayne_Hall_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '01892_Anonymous.json': [{'topic': '013', 'confidence': '1.0'}],
#  '01830_Jason_Garman_Redacted.json': [{'topic': '000',
#    'confidence': '0.291663'},
#   {'topic': '001', 'confidence': '0.255504'},
#   {'topic': '004', 'confidence': '0.18191'},
#   {'topic': '005', 'confidence': '0.138249'},
#   {'topic': '008', 'confidence': '0.091499'},
#   {'topic': '017', 'confidence': '0.041174'}],
#  '01949_Hugh_Rankin_Thorpe_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '09047_Katy_Steele_Redacted.json': [{'topic': '024',
#    'confidence': '1.0'}],
#  '09739_Anonymous.json': [{'topic': '009', 'confidence': '1.0'}],
#  '08319_Fiona_Summerfield_Redacted.json': [{'topic': '008',
#    'confidence': '1.0'}],
#  '05274_Anonymous.json': [{'topic': '006', 'confidence': '1.0'}],
#  '09505_Rachel_Amanda_Felicia_Harvey-Lees-Green_Redacted.json': [{'topic': '015',
#    'confidence': '1.0'}],
#  '00168_Mark_Houghton_Brown_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '09416_Nicola_Patrick_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '07285_Lyn_Minifie_Redacted.json': [{'topic': '004',
#    'confidence': '1.0'}],
#  '00972_Georg_Florian_Zellmer_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '09266_Sarah_Gay_Lightbody_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '09679_Margaret_Susan_Baker_Redacted.json': [{'topic': '013',
#    'confidence': '1.0'}],
#  '09418_Paul_John_Taylor_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '01652_Alison_Clarke_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '01968_Peter_Dowden_Redacted.json': [{'topic': '013',
#    'confidence': '1.0'}],
#  '01677_Fliss_Butcher_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '00084_Anonymous.json': [{'topic': '004', 'confidence': '1.0'}],
#  '09406_Robina_Stevens_Redacted.json': [{'topic': '001',
#    'confidence': '0.282523'},
#   {'topic': '000', 'confidence': '0.27848'},
#   {'topic': '008', 'confidence': '0.120657'},
#   {'topic': '002', 'confidence': '0.117494'},
#   {'topic': '004', 'confidence': '0.085232'},
#   {'topic': '005', 'confidence': '0.047749'},
#   {'topic': '019', 'confidence': '0.034438'},
#   {'topic': '009', 'confidence': '0.033427'}],
#  '09338_John_Cocks_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '09471_Maureen_St.Clair_Dunn_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '08842_Anonymous.json': [{'topic': '002', 'confidence': '0.561707'},
#   {'topic': '000', 'confidence': '0.228526'},
#   {'topic': '004', 'confidence': '0.130013'},
#   {'topic': '008', 'confidence': '0.079753'}],
#  '00017_Simon_Jackson_Redacted.json': [{'topic': '004',
#    'confidence': '1.0'}],
#  '00706_David_Martyn_White_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '00668_Ross_Lawrenson_Redacted.json': [{'topic': '005',
#    'confidence': '1.0'}],
#  '02542_Gerry_Essenberg_Redacted.json': [{'topic': '004',
#    'confidence': '1.0'}],
#  '00082_Gavin_Sims_Redacted.json': [{'topic': '017',
#    'confidence': '1.0'}],
#  '08017_Keith_Allum_Redacted.json': [{'topic': '013',
#    'confidence': '1.0'}],
#  '02593_Garvin_Filby_Redacted.json': [{'topic': '008',
#    'confidence': '1.0'}],
#  '08211_William_David_Rudd_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '09155_Steven_Rymell_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '00123_Lee_Heller_Redacted.json': [{'topic': '024',
#    'confidence': '1.0'}],
#  '08239_Helen_Gafa_Redacted.json': [{'topic': '000',
#    'confidence': '0.814781'},
#   {'topic': '001', 'confidence': '0.185219'}],
#  '00632_Anonymous.json': [{'topic': '002', 'confidence': '1.0'}],
#  '00024_George_Green_Redacted.json': [{'topic': '003',
#    'confidence': '1.0'}],
#  "05181_Kristine_O'Connor_Redacted (1).json": [{'topic': '000',
#    'confidence': '0.814781'},
#   {'topic': '001', 'confidence': '0.185219'}],
#  '03900_Rachel_Edwards_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '04396_Daniela_Bagozzi_Redacted.json': [{'topic': '004',
#    'confidence': '1.0'}],
#  '09396_Janet_Pereira_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '02621_Anonymous.json': [{'topic': '005', 'confidence': '1.0'}],
#  '00107_Cameron_Fulton_Redacted.json': [{'topic': '004',
#    'confidence': '1.0'}],
#  '08527_Artur_Francisco_Redacted.json': [{'topic': '001',
#    'confidence': '0.221058'},
#   {'topic': '002', 'confidence': '0.213368'},
#   {'topic': '000', 'confidence': '0.193555'},
#   {'topic': '008', 'confidence': '0.10655'},
#   {'topic': '005', 'confidence': '0.103947'},
#   {'topic': '004', 'confidence': '0.068714'},
#   {'topic': '025', 'confidence': '0.05173'},
#   {'topic': '003', 'confidence': '0.041076'}],
#  '00066_Anonymous.json': [{'topic': '024', 'confidence': '1.0'}],
#  '00186_Mike_John_Brook_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '02439_Dominic_G_Harvey_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '02495_Anonymous.json': [{'topic': '005', 'confidence': '1.0'}],
#  '09079_Piero_Lavo_Redacted.json': [{'topic': '003',
#    'confidence': '1.0'}],
#  '01685_Mary_Morgan-Richards_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '02127_Anonymous.json': [{'topic': '000', 'confidence': '1.0'}],
#  '09134_K_Harrison_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '07471_Karl_Menzies_Redacted.json': [{'topic': '008',
#    'confidence': '1.0'}],
#  '00160_Michael_John_Winch_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '08408_Inger_Perkins_Redacted.json': [{'topic': '007',
#    'confidence': '1.0'}],
#  '00092_Micheal_George_Denton_Redacted.json': [{'topic': '008',
#    'confidence': '1.0'}],
#  '00219_Anonymous.json': [{'topic': '001', 'confidence': '1.0'}],
#  '09242_Anonymous.json': [{'topic': '000', 'confidence': '0.814781'},
#   {'topic': '001', 'confidence': '0.185219'}],
#  '00118_Ivan_Miskovic.json': [{'topic': '024', 'confidence': '1.0'}],
#  '09250_Lawrence_John_Carter_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '01785_Andrew_Hollis_Redacted.json': [{'topic': '000',
#    'confidence': '0.573574'},
#   {'topic': '004', 'confidence': '0.141705'},
#   {'topic': '002', 'confidence': '0.101507'},
#   {'topic': '001', 'confidence': '0.099919'},
#   {'topic': '019', 'confidence': '0.047066'},
#   {'topic': '008', 'confidence': '0.036228'}],
#  '02569_Anonymous.json': [{'topic': '001', 'confidence': '1.0'}],
#  '00721_Abigail_Jane_Wills_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '09113_Anonymous.json': [{'topic': '002', 'confidence': '1.0'}],
#  '08272_Anonymous.json': [{'topic': '002', 'confidence': '1.0'}],
#  '01593_Anonymous.json': [{'topic': '002', 'confidence': '1.0'}],
#  '09361_John_and_Christine_Pedersen_Redacted.json': [{'topic': '008',
#    'confidence': '1.0'}],
#  '08605_Rachel_Highton_Redacted.json': [{'topic': '025',
#    'confidence': '1.0'}],
#  '01009_Anonymous.json': [{'topic': '002', 'confidence': '1.0'}],
#  '05302_Ivan_Johnstone_Redacted.json': [{'topic': '002',
#    'confidence': '0.398458'},
#   {'topic': '000', 'confidence': '0.115619'},
#   {'topic': '004', 'confidence': '0.088318'},
#   {'topic': '008', 'confidence': '0.072'},
#   {'topic': '024', 'confidence': '0.071851'},
#   {'topic': '003', 'confidence': '0.0647'},
#   {'topic': '001', 'confidence': '0.047672'},
#   {'topic': '013', 'confidence': '0.046195'},
#   {'topic': '005', 'confidence': '0.040503'},
#   {'topic': '020', 'confidence': '0.029651'}],
#  '07989_Anonymous.json': [{'topic': '004', 'confidence': '1.0'}],
#  '01770_Christopher_John_Fidoe_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '09215_Trevor_Smith_Redacted.json': [{'topic': '008',
#    'confidence': '1.0'}],
#  '02449_Peter_Harley_Deacon_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '01136_Gill_Lambert_Redacted.json': [{'topic': '008',
#    'confidence': '1.0'}],
#  '00635_Stevie_Radovanovich_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  "05181_Kristine_O'Connor_Redacted.json": [{'topic': '000',
#    'confidence': '0.814781'},
#   {'topic': '001', 'confidence': '0.185219'}],
#  '01485_Deanne_Helen_Smeaton_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '01708_Anonymous.json': [{'topic': '000', 'confidence': '0.814781'},
#   {'topic': '001', 'confidence': '0.185219'}],
#  '02504_Lisa_Jane_McEwan_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '09107_Aaron_Erb_Redacted.json': [{'topic': '006',
#    'confidence': '1.0'}],
#  '02130_Anonymous.json': [{'topic': '004', 'confidence': '1.0'}],
#  '01730_Jack_Haughton_Redacted.json': [{'topic': '008',
#    'confidence': '1.0'}],
#  '00144_Jeff_Vesey_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '01094_Victoria_Murphy_Redacted.json': [{'topic': '002',
#    'confidence': '0.611124'},
#   {'topic': '029', 'confidence': '0.203618'},
#   {'topic': '008', 'confidence': '0.185258'}],
#  '07674_Josephine_Serrallach_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '02546_Anonymous.json': [{'topic': '002', 'confidence': '1.0'}],
#  '00150_Virginia_Frances_Nelson_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '09586_Peter_Francis_Kerr_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '09259_Gregorius_Brouwer_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '00595_Andrew_Bruce_Tait_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '00699_Anoushka_Numans_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '09246_Anonymous.json': [{'topic': '011', 'confidence': '1.0'}],
#  "08462_Jane_O'Shea_Redacted.json": [{'topic': '010',
#    'confidence': '1.0'}],
#  '00044_Benjamin_Thomas_Hay-Smith_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '01671_Judith_Bartosh_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '09332_Mary_Dinniss_Redacted.json': [{'topic': '025',
#    'confidence': '1.0'}],
#  '01635_Glen_Robert_Harland_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '09428_Neville_Douglas_Peat_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '09500_Thelma_Greer_Redacted.json': [{'topic': '004',
#    'confidence': '1.0'}],
#  '00718_Anonymous.json': [{'topic': '008', 'confidence': '1.0'}],
#  '09196_Glenville_Gordon_Stiles_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '08008_Debbie_Laing_Redacted.json': [{'topic': '005',
#    'confidence': '1.0'}],
#  '02520_Daniel_Redacted.json': [{'topic': '002', 'confidence': '1.0'}],
#  '00739_Anonymous.json': [{'topic': '011', 'confidence': '1.0'}],
#  '07364_Bruce_Crothers.json': [{'topic': '005', 'confidence': '1.0'}],
#  '02433_Carsten_Bockemuehl_Redacted.json': [{'topic': '000',
#    'confidence': '0.378754'},
#   {'topic': '005', 'confidence': '0.209953'},
#   {'topic': '008', 'confidence': '0.186071'},
#   {'topic': '004', 'confidence': '0.122784'},
#   {'topic': '020', 'confidence': '0.102437'}],
#  '09192_Pippa_Anne_Auld_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '02468_Carol_Lynn_Blair_Redacted.json': [{'topic': '001',
#    'confidence': '1.0'}],
#  '01197_Chris_Rapson_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '00117_R_Ca_Redacted.json': [{'topic': '001', 'confidence': '1.0'}],
#  '02387_Anonymous.json': [{'topic': '001', 'confidence': '1.0'}],
#  '00230_Anonymous.json': [{'topic': '002', 'confidence': '1.0'}],
#  '09504_William_Damian_Wrigley_Redacted.json': [{'topic': '025',
#    'confidence': '1.0'}],
#  '01683_Nadia_Tenouri_Redacted.json': [{'topic': '005',
#    'confidence': '1.0'}],
#  '01658_Catherine_Mary_Gibbs_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}],
#  '01752_Bryce_Marshall_Redacted.json': [{'topic': '000',
#    'confidence': '0.814781'},
#   {'topic': '001', 'confidence': '0.185219'}],
#  '00037_Ronald_Richard_Apperley_Miller_Redacted.json': [{'topic': '002',
#    'confidence': '1.0'}],
#  '00126_Malcolm_Ley_Stuart_McAll_Redacted.json': [{'topic': '000',
#    'confidence': '1.0'}]}

# %%
topic_terms = {}

with open('zero-carbon-bill/topic-modelling/topic-terms.csv', newline='') as topic_terms_file:
    reader = csv.reader(topic_terms_file, delimiter=',')
    for row in reader:
        if row[0] == 'topic':
            next
        else:
            topic_number = row[0]
            item = {'term': row[1], 'weight': row[2]}
            if topic_terms.get(topic_number, None) is None:
                topic_terms[topic_number] = []
            topic_terms[topic_number].append(item)

for key, value in topic_terms.items():
    topic_terms[key] = sorted(value, key=sort_by_weight, reverse=True)
    
topic_terms
# Out:
# {'000': [{'term': 'future', 'weight': '0.052680425'},
#   {'term': 'important', 'weight': '0.0458398'},
#   {'term': 'work', 'weight': '0.04049393'},
#   {'term': 'country', 'weight': '0.029050583'},
#   {'term': 'green', 'weight': '0.029000932'},
#   {'term': 'generation', 'weight': '0.021251926'},
#   {'term': 'act', 'weight': '0.021079408'},
#   {'term': 'policy', 'weight': '0.02003124'},
#   {'term': 'clean', 'weight': '0.01826601'},
#   {'term': 'kid', 'weight': '0.015781336'}],
#  '001': [{'term': 'issue', 'weight': '0.07793963'},
#   {'term': 'climate', 'weight': '0.046610046'},
#   {'term': 'party', 'weight': '0.04162657'},
#   {'term': 'effect', 'weight': '0.03978515'},
#   {'term': 'work', 'weight': '0.035376802'},
#   {'term': 'change', 'weight': '0.034182627'},
#   {'term': 'engagement', 'weight': '0.030500093'},
#   {'term': 'active', 'weight': '0.028885953'},
#   {'term': 'congratulation', 'weight': '0.02872793'},
#   {'term': 'handle', 'weight': '0.02868677'}],
#  '002': [{'term': 'emission', 'weight': '0.11570353'},
#   {'term': 'important', 'weight': '0.0862869'},
#   {'term': 'carbon', 'weight': '0.07416282'},
#   {'term': 'reduce', 'weight': '0.06442864'},
#   {'term': 'program', 'weight': '0.05130959'},
#   {'term': 'focus', 'weight': '0.04670449'},
#   {'term': 'act', 'weight': '0.04202552'},
#   {'term': 'cut', 'weight': '0.037868105'},
#   {'term': 'asap', 'weight': '0.036663577'},
#   {'term': 'waste', 'weight': '0.025089016'}],
#  '003': [{'term': 'time', 'weight': '0.13279434'},
#   {'term': 'long', 'weight': '0.07370009'},
#   {'term': 'zealand', 'weight': '0.059762213'},
#   {'term': 'crack', 'weight': '0.052592132'},
#   {'term': 'target', 'weight': '0.04890697'},
#   {'term': 'bold', 'weight': '0.041554544'},
#   {'term': 'essence', 'weight': '0.038140576'},
#   {'term': 'gut', 'weight': '0.03814044'},
#   {'term': 'implement', 'weight': '0.038056854'},
#   {'term': 'undertake', 'weight': '0.034632348'}],
#  '004': [{'term': 'important', 'weight': '0.13506885'},
#   {'term': 'world', 'weight': '0.110541485'},
#   {'term': 'nz', 'weight': '0.10672064'},
#   {'term': 'crucially', 'weight': '0.052913915'},
#   {'term': 'leader', 'weight': '0.04057271'},
#   {'term': 'country', 'weight': '0.03783156'},
#   {'term': 'small', 'weight': '0.03521353'},
#   {'term': 'area', 'weight': '0.02798521'},
#   {'term': 'global', 'weight': '0.024551077'},
#   {'term': 'population', 'weight': '0.023661507'}],
#  '005': [{'term': 'impact', 'weight': '0.14565592'},
#   {'term': 'international', 'weight': '0.092633724'},
#   {'term': 'tourism', 'weight': '0.088754885'},
#   {'term': 'include', 'weight': '0.07986587'},
#   {'term': 'border', 'weight': '0.06521611'},
#   {'term': 'risk', 'weight': '0.048607178'},
#   {'term': 'respond', 'weight': '0.03820408'},
#   {'term': 'track', 'weight': '0.036587495'},
#   {'term': 'air', 'weight': '0.023695277'},
#   {'term': 'organisation', 'weight': '0.02354485'}],
#  '006': [{'term': 'environment', 'weight': '0.17738117'},
#   {'term': 'website', 'weight': '0.14011948'},
#   {'term': 'ministry', 'weight': '0.13542363'},
#   {'term': 'exclude', 'weight': '0.09715516'},
#   {'term': 'precious', 'weight': '0.09159015'},
#   {'term': 'preserve', 'weight': '0.083614506'},
#   {'term': 'gift', 'weight': '0.08361192'},
#   {'term': 'consent', 'weight': '0.03672412'},
#   {'term': 'withhold', 'weight': '0.023180606'},
#   {'term': 'post', 'weight': '0.022057272'}],
#  '007': [{'term': 'waste', 'weight': '0.13210699'},
#   {'term': 'money', 'weight': '0.09314521'},
#   {'term': 'program', 'weight': '0.09072642'},
#   {'term': 'carbon', 'weight': '0.08105112'},
#   {'term': 'change', 'weight': '0.06984367'},
#   {'term': 'people', 'weight': '0.058780532'},
#   {'term': 'emission', 'weight': '0.0544948'},
#   {'term': 'country', 'weight': '0.04519163'},
#   {'term': 'benefit', 'weight': '0.037449554'},
#   {'term': 'issue', 'weight': '0.03198842'}],
#  '008': [{'term': 'change', 'weight': '0.16592634'},
#   {'term': 'system', 'weight': '0.12883617'},
#   {'term': 'current', 'weight': '0.12485177'},
#   {'term': 'focus', 'weight': '0.048579704'},
#   {'term': 'business', 'weight': '0.027052004'},
#   {'term': 'kid', 'weight': '0.014750724'},
#   {'term': 'ambitious', 'weight': '0.013986404'},
#   {'term': 'front', 'weight': '0.013190558'},
#   {'term': 'relieve', 'weight': '0.011923948'},
#   {'term': 'proposal', 'weight': '0.011370363'}],
#  '009': [{'term': 'information', 'weight': '0.32275966'},
#   {'term': 'share', 'weight': '0.13915023'},
#   {'term': 'good', 'weight': '0.13327816'},
#   {'term': 'attach', 'weight': '0.120531246'},
#   {'term': 'make', 'weight': '0.07190349'},
#   {'term': 'sound', 'weight': '0.06491089'},
#   {'term': 'public', 'weight': '0.05634822'},
#   {'term': 'decision', 'weight': '0.050314948'},
#   {'term': 'supply', 'weight': '0.040803183'}],
#  '010': [{'term': 'action', 'weight': '0.36835292'},
#   {'term': 'cop', 'weight': '0.15213133'},
#   {'term': 'visionary', 'weight': '0.15212548'},
#   {'term': 'moral', 'weight': '0.060785208'},
#   {'term': 'need', 'weight': '0.05392617'},
#   {'term': 'start', 'weight': '0.041056473'},
#   {'term': 'time', 'weight': '0.04043795'},
#   {'term': 'pragmatic', 'weight': '0.037705194'},
#   {'term': 'perspective', 'weight': '0.03721963'},
#   {'term': 'ignore', 'weight': '0.028860863'}],
#  '011': [{'term': 'address', 'weight': '0.3107191'},
#   {'term': 'email', 'weight': '0.2750687'},
#   {'term': 'disclose', 'weight': '0.2066208'},
#   {'term': 'phone', 'weight': '0.04353187'},
#   {'term': 'site', 'weight': '0.03932667'},
#   {'term': 'note', 'weight': '0.033244178'},
#   {'term': 'web', 'weight': '0.024624614'},
#   {'term': 'e.mail', 'weight': '0.023318183'},
#   {'term': 'share', 'weight': '0.013646483'},
#   {'term': 'surname', 'weight': '0.008547078'}],
#  '012': [{'term': 'priority', 'weight': '0.1761363'},
#   {'term': 'top', 'weight': '0.16534746'},
#   {'term': "govt's", 'weight': '0.16323294'},
#   {'term': 'regard', 'weight': '0.16322152'},
#   {'term': 'address', 'weight': '0.045425277'},
#   {'term': 'focus', 'weight': '0.0401319'},
#   {'term': 'people', 'weight': '0.036300775'},
#   {'term': 'supplementary', 'weight': '0.025131313'},
#   {'term': 'ministry', 'weight': '0.01628344'},
#   {'term': 'usual', 'weight': '0.01135216'}],
#  '013': [{'term': 'tax', 'weight': '0.23724855'},
#   {'term': 'ev', 'weight': '0.17451127'},
#   {'term': 'subsidy', 'weight': '0.17051528'},
#   {'term': 'back', 'weight': '0.16901778'},
#   {'term': 'electric', 'weight': '0.035639726'},
#   {'term': 'good', 'weight': '0.029145714'},
#   {'term': 'introduce', 'weight': '0.022838661'},
#   {'term': 'vehicle', 'weight': '0.016341006'},
#   {'term': 'incentive', 'weight': '0.016149137'},
#   {'term': 'gst', 'weight': '0.013034813'}],
#  '014': [{'term': 'answer', 'weight': '0.19859684'},
#   {'term': 'case', 'weight': '0.19322242'},
#   {'term': 'tick', 'weight': '0.19282989'},
#   {'term': 'box', 'weight': '0.19252184'},
#   {'term': 'business', 'weight': '0.049465913'},
#   {'term': 'bill', 'weight': '0.028850535'},
#   {'term': 'time', 'weight': '0.017615395'},
#   {'term': 'key', 'weight': '0.016996857'},
#   {'term': 'focus', 'weight': '0.01698564'},
#   {'term': 'country', 'weight': '0.015036915'}],
#  '015': [{'term': 'document', 'weight': '0.31652653'},
#   {'term': 'fantastic', 'weight': '0.2984112'},
#   {'term': 'discussion', 'weight': '0.28003076'},
#   {'term': 'putt', 'weight': '0.036301635'},
#   {'term': 'provide', 'weight': '0.023489984'},
#   {'term': 'consultation', 'weight': '0.022454092'},
#   {'term': 'easy', 'weight': '0.011717514'},
#   {'term': 'straightforward', 'weight': '0.011068319'}],
#  '016': [{'term': 'level', 'weight': '0.21933216'},
#   {'term': 'high', 'weight': '0.20494124'},
#   {'term': 'urgency', 'weight': '0.2029609'},
#   {'term': 'prioritise', 'weight': '0.20183815'},
#   {'term': 'bill', 'weight': '0.034151934'},
#   {'term': 'business', 'weight': '0.027950712'},
#   {'term': 'emission', 'weight': '0.01914937'},
#   {'term': 'agriculture', 'weight': '0.016041243'},
#   {'term': 'massive', 'weight': '0.013707493'},
#   {'term': 'work', 'weight': '0.009518109'}],
#  '017': [{'term': 'support', 'weight': '0.4390968'},
#   {'term': 'bill', 'weight': '0.15324016'},
#   {'term': 'initiative', 'weight': '0.14359055'},
#   {'term': 'strongly', 'weight': '0.14250778'},
#   {'term': 'industry', 'weight': '0.036348034'},
#   {'term': 'farm', 'weight': '0.03161952'},
#   {'term': 'direction', 'weight': '0.027725063'},
#   {'term': 'hemp', 'weight': '0.025872095'}],
#  '018': [{'term': 'dairy', 'weight': '0.24807195'},
#   {'term': 'stock', 'weight': '0.24768895'},
#   {'term': 'beef', 'weight': '0.24630238'},
#   {'term': 'lessen', 'weight': '0.24546067'}],
#  '019': [{'term': 'direction', 'weight': '0.08174109'},
#   {'term': 'usual', 'weight': '0.053212166'},
#   {'term': 'waste', 'weight': '0.052739352'},
#   {'term': 'program', 'weight': '0.048320893'},
#   {'term': 'submission', 'weight': '0.034660995'},
#   {'term': 'reduce', 'weight': '0.030636154'},
#   {'term': 'precious', 'weight': '0.029321374'},
#   {'term': 'government', 'weight': '0.028351175'},
#   {'term': 'act', 'weight': '0.027776355'},
#   {'term': 'money', 'weight': '0.026552333'}],
#  '020': [{'term': 'bill', 'weight': '0.37915838'},
#   {'term': 'emission', 'weight': '0.04055138'},
#   {'term': 'long', 'weight': '0.031076776'},
#   {'term': 'initiative', 'weight': '0.030255836'},
#   {'term': 'tree', 'weight': '0.029727938'},
#   {'term': 'area', 'weight': '0.023750903'},
#   {'term': 'policy', 'weight': '0.022301191'},
#   {'term': 'make', 'weight': '0.021326063'},
#   {'term': 'completely', 'weight': '0.014691308'},
#   {'term': 'word', 'weight': '0.0144102415'}],
#  '021': [{'term': 'approach', 'weight': '0.3418278'},
#   {'term': 'integrate', 'weight': '0.329517'},
#   {'term': 'collaborative', 'weight': '0.32865518'}],
#  '022': [{'term': 'collaboration', 'weight': '0.33761188'},
#   {'term': 'essential', 'weight': '0.3335809'},
#   {'term': 'agency', 'weight': '0.3288072'}],
#  '023': [{'term': 'publish', 'weight': '0.44323286'},
#   {'term': 'detail', 'weight': '0.23462844'},
#   {'term': 'website', 'weight': '0.17865817'},
#   {'term': 'consent', 'weight': '0.08791729'},
#   {'term': 'submission', 'weight': '0.043435633'},
#   {'term': 'private', 'weight': '0.0121276'}],
#  '024': [{'term': 'environment', 'weight': '0.04497236'},
#   {'term': 'note', 'weight': '0.042931452'},
#   {'term': 'fantastic', 'weight': '0.039051518'},
#   {'term': 'emission', 'weight': '0.03660018'},
#   {'term': 'discussion', 'weight': '0.035055466'},
#   {'term': 'long', 'weight': '0.03029156'},
#   {'term': 'precious', 'weight': '0.025638603'},
#   {'term': 'government', 'weight': '0.024251204'},
#   {'term': 'preserve', 'weight': '0.021717291'},
#   {'term': 'economic', 'weight': '0.019004708'}],
#  '025': [{'term': 'support', 'weight': '0.69238317'},
#   {'term': 'carbon', 'weight': '0.029509988'},
#   {'term': 'decision', 'weight': '0.023054235'},
#   {'term': 'tree', 'weight': '0.015868908'},
#   {'term': 'put', 'weight': '0.015810458'},
#   {'term': 'economic', 'weight': '0.011443903'},
#   {'term': 'pass', 'weight': '0.010778524'},
#   {'term': 'plant', 'weight': '0.00911576'},
#   {'term': 'difference', 'weight': '0.0089967195'},
#   {'term': 'live', 'weight': '0.008823426'}],
#  '026': [{'term': 'information', 'weight': '0.7575248'},
#   {'term': 'note', 'weight': '0.1177957'},
#   {'term': 'additional', 'weight': '0.07108766'},
#   {'term': 'disclose', 'weight': '0.014220106'},
#   {'term': 'site', 'weight': '0.011701745'},
#   {'term': 'web', 'weight': '0.0070592184'},
#   {'term': 'e.mail', 'weight': '0.006332564'}],
#  '027': [{'term': 'information', 'weight': '0.3948641'},
#   {'term': 'attach', 'weight': '0.34979916'},
#   {'term': 'additional', 'weight': '0.12866443'},
#   {'term': 'note', 'weight': '0.12667231'}],
#  '028': [{'term': 'part', 'weight': '0.37879884'},
#   {'term': 'key', 'weight': '0.33219087'},
#   {'term': 'take', 'weight': '0.16582868'},
#   {'term': 'finally', 'weight': '0.049061563'},
#   {'term': 'government', 'weight': '0.044237975'},
#   {'term': 'scary', 'weight': '0.029882051'}],
#  '029': [{'term': 'time', 'weight': '0.1104484'},
#   {'term': 'focus', 'weight': '0.059058674'},
#   {'term': 'document', 'weight': '0.051473618'},
#   {'term': 'address', 'weight': '0.0497674'},
#   {'term': 'effect', 'weight': '0.047978457'},
#   {'term': 'reduce', 'weight': '0.042304225'},
#   {'term': 'share', 'weight': '0.036827877'},
#   {'term': 'initiative', 'weight': '0.03678464'},
#   {'term': 'bold', 'weight': '0.03489119'},
#   {'term': 'start', 'weight': '0.030104717'}]}

# %%
input_file_pattern = 'zero-carbon-bill/input/*.json'
input_folder_name = 'zero-carbon-bill/input/'

filenames = glob(input_file_pattern)

# %%
print(key_phrases[1])
# Out:
# {'File': '00002_Jennifer_Valentine_Redacted.json', 'KeyPhrases': [{'BeginOffset': 19, 'EndOffset': 27, 'Score': 1.0, 'Text': 'our most'}, {'BeginOffset': 37, 'EndOffset': 50, 'Score': 0.9999997317792233, 'Text': 'gift, we must'}]}

# %%
def key_phrases_for_submission(number):
    submission_phrases = key_phrases[number]
    file_name = input_folder_name + submission_phrases['File']
    with open(file_name) as f:
        submission_contents = f.read()
    print('Full text:')
    print(submission_contents)
    phrases = submission_phrases['KeyPhrases']
    for phrase in phrases:
        print('Key phrase:')
        print(phrase['Text'])
        print('Score:')
        print(phrase['Score'])
    return(submission_phrases['KeyPhrases'])

# %%
def sentiment_analysis_for_submission(filename):    
    if input_folder_name in filename:
        input_file_name = filename
        filename = filename.replace(input_folder_name, '')
    else:
        input_file_name = input_folder_name + filename

    sentiment = sentiment_analysis[filename]
    
    with open(input_file_name) as f:
        submission_contents = f.readlines()
        
#   this is a dict:  {}

    labelled_line_numbers = []
    
    for l in sentiment:
        line_number = l['Line']
        
        sentiment_details = {}
        
        predicted_sentiment = l['Sentiment']
        sentiment_details['sentiment'] = predicted_sentiment.lower()
        sentiment_details['confidence'] = l['SentimentScore'][predicted_sentiment.title()]
                
        line_details = {}
        
        line_details['line_number'] = line_number
        line_details['original_text'] = submission_contents[line_number]
        line_details['sentiment'] = sentiment_details
        
        labelled_line_numbers.append(line_details)


    return(sorted(labelled_line_numbers, key=sort_by_line_number))

# %%
a = sentiment_analysis_for_submission('00018_Leigh_Nicholson_Redacted.json')

for line in a:
    print(line['original_text'])
    print(line['sentiment'])
    print('***')
# Out:
# I think this is a fantastic and well researched document which makes an important first step. Congratulations! In order for this to be of
#
# {'sentiment': 'positive', 'confidence': 0.9997685551643372}
# ***
#
#
# {'sentiment': 'neutral', 'confidence': 0.9320765733718872}
# ***
# maximum benefit - we need to ensure a high proportion of NZ people engage with it. This requires a lot of targeted marketing - This
#
# {'sentiment': 'neutral', 'confidence': 0.43769529461860657}
# ***
# needs a very strong Stakeholder and Communications Management Strategy. A great job and well done . I would welcome any further
#
# {'sentiment': 'positive', 'confidence': 0.9604456424713135}
# ***
# discussions on the subject
#
# {'sentiment': 'neutral', 'confidence': 0.991081714630127}
# ***

# %%
key_phrases_for_submission(13)
# Out:
# Full text:
# The government should set a 2025 Target Policy and legislation should be introduced within 6 months.
#
# Key phrase:
# Target
# Score:
# 1.0
# Key phrase:
# Policy
# Score:
# 1.0
# Key phrase:
# introduced
# Score:
# 0.9999997615814777
# Key phrase:
# months
# Score:
# 0.9999997615814777
# [{'BeginOffset': 33, 'EndOffset': 39, 'Score': 1.0, 'Text': 'Target'},
#  {'BeginOffset': 40, 'EndOffset': 46, 'Score': 1.0, 'Text': 'Policy'},
#  {'BeginOffset': 73,
#   'EndOffset': 83,
#   'Score': 0.9999997615814777,
#   'Text': 'introduced'},
#  {'BeginOffset': 93,
#   'EndOffset': 99,
#   'Score': 0.9999997615814777,
#   'Text': 'months'}]

# %%
# Out:
# {u'File': u'00089_Jenny_Ritchie_Redacted.json',
#  u'KeyPhrases': [{u'BeginOffset': 3,
#    u'EndOffset': 12,
#    u'Score': 0.9952778801057404,
#    u'Text': u'is such a'}]}
